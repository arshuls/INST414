# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# Load the CSV file
data = pd.read_csv("2023_nba_player_stats.csv")

# Select relevant features for similarity computation (excluding 'Min')
features = ['PTS', 'FG%', '3P%', 'FT%', 'REB', 'AST', 'STL', 'BLK']

# Normalize the data
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data[features])

# Compute cosine similarity
similarity_matrix = cosine_similarity(data_normalized)

# Define function to get top N similar players with their data
def get_top_similar_players(player_index, similarity_matrix, data):
    # Get similarity scores for the player
    player_similarities = similarity_matrix[player_index]
    # Sort indices based on similarity scores
    similar_player_indices = player_similarities.argsort()[::-1] # Exclude the player itself
    # Get player names
    similar_players = data.iloc[similar_player_indices]['PName'].values
    return similar_players

# Get top 10 similar players for Jayson Tatum and Joel Embiid
jayson_top_similar_players = get_top_similar_players(jayson_index, similarity_matrix, data)
joel_top_similar_players = get_top_similar_players(joel_index, similarity_matrix, data)

# Display only the top 10 similar players
print("Top 10 similar players to Jayson Tatum:")
print(jayson_top_similar_players[:10])  # Slice to include only the first 10 elements
print("\nTop 10 similar players to Joel Embiid:")
print(joel_top_similar_players[:10]) 
similar_players_dict = {}

# Populate the dictionary
similar_players_dict['Jayson Tatum'] = list(jayson_top_similar_players)

# Display the dictionary
print("\nDictionary of similar players to Jayson Tatum:")
print(similar_players_dict)
# Out:
# Top 10 similar players to Jayson Tatum:
# ['Jayson Tatum' 'Paolo Banchero' 'Pascal Siakam' 'Jaylen Brown'
#  'LeBron James' 'Julius Randle' 'Luka Doncic' 'Giannis Antetokounmpo'
#  'Joel Embiid' 'Zach LaVine']
#
# Top 10 similar players to Joel Embiid:
# ['Joel Embiid' 'Kristaps Porzingis' 'Anthony Davis' 'Jayson Tatum'
#  'Paolo Banchero' 'Giannis Antetokounmpo' 'Evan Mobley' 'P.J. Washington'
#  'Aaron Gordon' 'Pascal Siakam']
#
# Dictionary of similar players to Jayson Tatum:
# {'Jayson Tatum': ['Jayson Tatum', 'Paolo Banchero', 'Pascal Siakam', 'Jaylen Brown', 'LeBron James', 'Julius Randle', 'Luka Doncic', 'Giannis Antetokounmpo', 'Joel Embiid', 'Zach LaVine', 'DeMar DeRozan', 'Kyle Kuzma', 'Jalen Green', 'Mikal Bridges', 'CJ McCollum', 'Kyrie Irving', 'Shai Gilgeous-Alexander', 'Lauri Markkanen', 'Franz Wagner', "De'Aaron Fox", 'RJ Barrett', 'Bam Adebayo', 'Keldon Johnson', 'Anthony Edwards', 'Donovan Mitchell', 'Scottie Barnes', 'Stephen Curry', 'Ja Morant', 'Josh Giddey', 'Nikola Vucevic', 'Aaron Gordon', 'Kristaps Porzingis', 'Buddy Hield', 'Jordan Poole', 'Paul George', 'Damian Lillard', 'Terry Rozier', 'Tyler Herro', 'Alperen Sengun', 'Nikola Jokic', 'Klay Thompson', 'Immanuel Quickley', 'Jaden Ivey', 'Devin Booker', 'P.J. Washington', 'Jalen Brunson', 'Kawhi Leonard', 'Bennedict Mathurin', 'Tobias Harris', 'Dejounte Murray', 'Jerami Grant', 'Desmond Bane', 'Harrison Barnes', 'Kevin Porter Jr.', 'Luguentz Dort', 'Jimmy Butler', 'Jamal Murray', 'Jrue Holiday', 'Kenyon Martin Jr.', 'Domantas Sabonis', 'Dillon Brooks', 'Anthony Davis', 'Kevin Huerter', 'Spencer Dinwiddie', 'Jordan Clarkson', 'Deandre Ayton', 'Russell Westbrook', 'Keegan Murray', "D'Angelo Russell", 'Saddiq Bey', 'Malik Beasley', 'Jabari Smith Jr.', 'Caris LeVert', 'Kevin Durant', 'Kelly Olynyk', 'Deni Avdija', 'Bruce Brown', 'Evan Mobley', 'Tim Hardaway Jr.', 'Bradley Beal', 'Christian Wood', 'Derrick White', 'Jalen Williams', "Royce O'Neale", 'Anfernee Simons', 'James Harden', 'Trey Murphy III', 'Malcolm Brogdon', 'Wendell Carter Jr.', 'Michael Porter Jr.', 'Jaden McDaniels', 'Josh Hart', 'Malik Monk', 'Darius Garland', 'Tyrese Maxey', 'John Collins', 'Jusuf Nurkic', 'Brandon Ingram', 'Fred VanVleet', 'Kelly Oubre Jr.', "De'Andre Hunter", 'Bobby Portis', 'Bojan Bogdanovic', 'Zach Collins', 'Max Strus', 'Naji Marshall', 'Jeremy Sochan', 'Talen Horton-Tucker', 'Trae Young', 'Santi Aldama', 'LaMelo Ball', 'Jalen McDaniels', 'Markelle Fultz', 'Naz Reid', 'Jonas Valanciunas', 'Norman Powell', 'Quentin Grimes', 'Jarrett Allen', 'Kyle Anderson', 'Tari Eason', 'Caleb Martin', 'Patrick Williams', 'Jarred Vanderbilt', 'Shaedon Sharpe', 'Cole Anthony', 'Grant Williams', 'Marcus Morris Sr.', 'Aaron Nesmith', 'Tyrese Haliburton', 'Terance Mann', 'Torrey Craig', 'Ayo Dosunmu', 'O.G. Anunoby', 'Draymond Green', 'Tre Jones', 'Dennis Schroder', 'Jakob Poeltl', 'Gordon Hayward', 'Dorian Finney-Smith', 'Andrew Nembhard', 'Eric Gordon', 'Mason Plumlee', 'Chris Boucher', 'Jonathan Kuminga', 'Gary Trent Jr.', 'Tyus Jones', 'Reggie Bullock', 'Grayson Allen', 'Donte DiVincenzo', 'Al Horford', 'Kyle Lowry', 'Josh Okogie', 'Jevon Carter', 'Chris Paul', 'Coby White', 'Mike Conley', 'Nicolas Batum', 'Onyeka Okongwu', 'Austin Reaves', 'Marcus Smart', 'Andrew Wiggins', 'Jaylen Nowell', 'Bogdan Bogdanovic', 'Killian Hayes', 'Cedi Osman', 'Josh Richardson', 'Patrick Beverley', 'Keita Bates-Diop', 'Devin Vassell', 'Monte Morris', 'Herbert Jones', 'Kentavious Caldwell-Pope', 'Pat Connaughton', 'Myles Turner', "De'Anthony Melton", 'T.J. McConnell', 'Jalen Smith', 'Jalen Suggs', 'Isaiah Stewart', 'Zion Williamson', 'Rui Hachimura', 'Troy Brown Jr.', 'Isaiah Hartenstein', 'Precious Achiuwa', 'Rudy Gobert', 'Reggie Jackson', 'Dennis Smith Jr.', 'Larry Nance Jr.', 'Malaki Branham', "Devonte' Graham", 'Corey Kispert', 'Isaiah Joe', 'Bones Hyland', 'Gabe Vincent', 'Jalen Johnson', 'Bol Bol', 'Kevon Looney', 'Moritz Wagner', 'Jordan Goodwin', 'Jose Alvarado', 'Cameron Johnson', 'Tre Mann', 'Trey Lyles', 'Xavier Tillman', 'Kenrich Williams', 'Shake Milton', 'Alec Burks', 'David Roddy', 'Joe Harris', 'Clint Capela', 'Isaac Okoro', 'John Konchar', 'Jalen Duren', 'Hamidou Diallo', 'Brandon Clarke', 'Victor Oladipo', 'Josh Green', 'Sam Hauser', 'Kevin Love', 'Karl-Anthony Towns', 'Georges Niang', 'Ivica Zubac', 'Jordan Nwora', 'Trendon Watford', 'AJ Griffin', 'Jaren Jackson Jr.', 'Drew Eubanks', 'Terrence Ross', 'Oshae Brissett', 'Cameron Payne', 'Damion Lee', 'Davion Mitch ...

# %%
# Function to get similarity scores for top N similar players
def get_similarity_scores(player_index, similar_player_indices, similarity_matrix):
    # Get similarity scores for the top similar players
    similarity_scores = similarity_matrix[player_index, similar_player_indices]
    return similarity_scores

# Find indices of top 10 similar players for Jayson Tatum and Joel Embiid
jayson_similar_indices = data[data['PName'].isin(jayson_similar_players)].index.values
joel_similar_indices = data[data['PName'].isin(joel_similar_players)].index.values

# Get similarity scores for top 10 similar players to Jayson Tatum
jayson_similarity_scores = get_similarity_scores(jayson_index, jayson_similar_indices, similarity_matrix)

# Get similarity scores for top 10 similar players to Joel Embiid
joel_similarity_scores = get_similarity_scores(joel_index, joel_similar_indices, similarity_matrix)

# Print similarity scores for Jayson Tatum
print("\nSimilarity scores for top 10 similar players to Jayson Tatum:")
print(jayson_similarity_scores)

# Print similarity scores for Joel Embiid
print("\nSimilarity scores for top 10 similar players to Joel Embiid:")
print(joel_similarity_scores)
# Out:
# Similarity scores for top 10 similar players to Jayson Tatum:
# [0.98099206 0.98388431 0.98327169 0.98406603 0.98074956 0.97930784
#  0.99072187 0.99106775 0.98409681 0.9927205 ]
#
# Similarity scores for top 10 similar players to Joel Embiid:
# [0.98099206 0.97497229 0.96567247 0.96555947 0.98765994 0.98266475
#  0.97644833 0.97483501 0.97039368 0.96704438]

# %%
# Function to categorize similarity scores
def categorize_similarity_scores(similarity_scores):
    categories = []
    for score in similarity_scores:
        if score >= 0.90:
            categories.append("Very Similar")
        elif 0.80 <= score <= 0.89:
            categories.append("Moderately Similar")
        elif 0.7 <= score <= 0.79:
            categories.append("Less Similar")
    return categories

# Categorize similarity scores for Jayson Tatum
jayson_similarity_categories = categorize_similarity_scores(jayson_similarity_scores)

# Categorize similarity scores for Joel Embiid
joel_similarity_categories = categorize_similarity_scores(joel_similarity_scores)

# Print categories for Jayson Tatum
print("\nCategories for top 10 similar players to Jayson Tatum:")
print(jayson_similarity_categories)

# Print categories for Joel Embiid
print("\nCategories for top 10 similar players to Joel Embiid:")
print(joel_similarity_categories)
# Out:
# Categories for top 10 similar players to Jayson Tatum:
# ['Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar']
#
# Categories for top 10 similar players to Joel Embiid:
# ['Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar', 'Very Similar']

# %%
def get_all_similar_players_with_scores(player_index, similarity_matrix, data):
    # Get similarity scores for the player
    player_similarities = similarity_matrix[player_index]
    # Sort indices based on similarity scores
    similar_player_indices = player_similarities.argsort()[::-1][1:] # Exclude the player itself
    # Get player names
    similar_players = data.iloc[similar_player_indices]['PName'].values
    # Get similarity scores
    similarity_scores = player_similarities[similar_player_indices]
    return similar_players, similarity_scores

# Find the index of Jayson Tatum in the data
jayson_index = data.index[data['PName'] == 'Jayson Tatum'].tolist()[0]

# Get all similar players for Jayson Tatum along with their similarity scores
jayson_similar_players, jayson_similarity_scores = get_all_similar_players_with_scores(jayson_index, similarity_matrix, data)

# Create a dictionary to store similar players and their similarity scores
similar_players_dict = {}

# Populate the dictionary with similar players and their similarity scores
for player, score in zip(jayson_similar_players, jayson_similarity_scores):
    similar_players_dict[player] = score

# Display the dictionary
print("Similarity scores for players similar to Jayson Tatum:")
for player, score in similar_players_dict.items():
    print(player, score)
# Out:
# Similarity scores for players similar to Jayson Tatum:
# Paolo Banchero 0.9927205049819267
# Pascal Siakam 0.9910677514947449
# Jaylen Brown 0.9907218723481154
# LeBron James 0.9840968108491313
# Julius Randle 0.9840660311593127
# Luka Doncic 0.9838843115420738
# Giannis Antetokounmpo 0.9832716949276415
# Joel Embiid 0.9809920586076716
# Zach LaVine 0.9807495578806485
# DeMar DeRozan 0.9793078379574752
# Kyle Kuzma 0.9783934684394806
# Jalen Green 0.9773317608518364
# Mikal Bridges 0.9747468331224342
# CJ McCollum 0.9729858514286286
# Kyrie Irving 0.9719739601535338
# Shai Gilgeous-Alexander 0.9710785685974892
# Lauri Markkanen 0.9696479653771177
# Franz Wagner 0.9696454241110796
# De'Aaron Fox 0.969467571275337
# RJ Barrett 0.9690689388582499
# Bam Adebayo 0.9689780192583851
# Keldon Johnson 0.9685086241208964
# Anthony Edwards 0.9683709835127601
# Donovan Mitchell 0.9681589612801281
# Scottie Barnes 0.9674250678742424
# Stephen Curry 0.9665951778845921
# Ja Morant 0.965208388106513
# Josh Giddey 0.9649152864212112
# Nikola Vucevic 0.9640609265748883
# Aaron Gordon 0.9629943254075546
# Kristaps Porzingis 0.9623792738644352
# Buddy Hield 0.9623646004585733
# Jordan Poole 0.962059707704873
# Paul George 0.9618915960235448
# Damian Lillard 0.9603548132259798
# Terry Rozier 0.9595183907495739
# Tyler Herro 0.9589751388761512
# Alperen Sengun 0.9589525601411693
# Nikola Jokic 0.957986402760583
# Klay Thompson 0.9574639725638181
# Immanuel Quickley 0.9571715156420317
# Jaden Ivey 0.9571331852519553
# Devin Booker 0.9564178007575057
# P.J. Washington 0.9553523743861392
# Jalen Brunson 0.9553059133657921
# Kawhi Leonard 0.9543032098313154
# Bennedict Mathurin 0.9531905844279467
# Tobias Harris 0.9530722194870402
# Dejounte Murray 0.9528662194152248
# Jerami Grant 0.9525592560850035
# Desmond Bane 0.9514529322760054
# Harrison Barnes 0.9502464954638618
# Kevin Porter Jr. 0.9501790517784667
# Luguentz Dort 0.9500300184695158
# Jimmy Butler 0.9485642321197982
# Jamal Murray 0.9485491654409423
# Jrue Holiday 0.9479048800252805
# Kenyon Martin Jr. 0.9468639966468269
# Domantas Sabonis 0.9459988409398602
# Dillon Brooks 0.9458097983356276
# Anthony Davis 0.945417134398848
# Kevin Huerter 0.9444732345570522
# Spencer Dinwiddie 0.9435416493948299
# Jordan Clarkson 0.943491496926229
# Deandre Ayton 0.9418296584427431
# Russell Westbrook 0.940667583946705
# Keegan Murray 0.9404739207443152
# D'Angelo Russell 0.9392749046578394
# Saddiq Bey 0.9392336846712848
# Malik Beasley 0.9390734380901319
# Jabari Smith Jr. 0.9387476628175023
# Caris LeVert 0.9383802582222143
# Kevin Durant 0.9380170451504646
# Kelly Olynyk 0.9375890308897896
# Deni Avdija 0.9368976583755232
# Bruce Brown 0.9365724003222996
# Evan Mobley 0.9353050300888102
# Tim Hardaway Jr. 0.9346478620366613
# Bradley Beal 0.9343374971927173
# Christian Wood 0.9336423269682974
# Derrick White 0.9326706331723691
# Jalen Williams 0.9325371432310843
# Royce O'Neale 0.9291186980458868
# Anfernee Simons 0.9268673817966834
# James Harden 0.92634533210595
# Trey Murphy III 0.925830145842022
# Malcolm Brogdon 0.9254444181158504
# Wendell Carter Jr. 0.9251396000489099
# Michael Porter Jr. 0.9250700207178181
# Jaden McDaniels 0.924891609113557
# Josh Hart 0.9247493506414161
# Malik Monk 0.9247473286132672
# Darius Garland 0.9247255016838724
# Tyrese Maxey 0.9240233544747254
# John Collins 0.9233288161472052
# Jusuf Nurkic 0.9229533384278362
# Brandon Ingram 0.9225258630484511
# Fred VanVleet 0.9216679256003089
# Kelly Oubre Jr. 0.9206430561145371
# De'Andre Hunter 0.9202194755758708
# Bobby Portis 0.9181066018867775
# Bojan Bogdanovic 0.9176205322377388
# Zach Collins 0.9173442892639628
# Max Strus 0.9172826593799128
# Naji Marshall 0.9158935899891545
# Jeremy Sochan 0.9149334946039943
# Talen Horton-Tucker 0.9136694514075273
# Trae Young 0.9135284763406564
# Santi Aldama 0.9128843323914769
# LaMelo Ball 0.9120996449340145
# Jalen McDaniels 0.9116658956123587
# Markelle Fultz 0.9115363377036844
# Naz Reid 0.9110170918242494
# Jonas Valanciunas 0.910921696113231
# Norman Powell 0.9097178739948597
# Quentin Grimes 0.9095951453509445
# Jarrett Allen 0.9095193182043224
# Kyle Anderson 0.9093689329267086
# Tari Eason 0.9093342487192593
# Caleb Martin 0.9083895838499836
# Patrick Williams 0.9079184667475383
# Jarred Vanderbilt 0.90765499383358
# Shaedon Sharpe 0.9074457857473901
# Cole Anthony 0.907178777648903
# Grant Williams 0.9055257782318733
# Marcus Morris Sr. 0.9046220442745293
# Aaron Nesmith 0.9044958913960142
# Tyrese Haliburton 0.9044267671819926
# Terance Mann 0.903205754001861
# Torrey Craig 0.9031734946957156
# Ayo Dosunmu 0.9028758655467822
# O.G. Anunoby 0.9027339162196746
# Draymond Green 0.9015958647189855
# Tre Jones 0.9009970364964439
# Dennis Schroder 0.9009536673494101
# Jakob Poeltl 0.8997776544326804
# Gordon Hayward 0.89913610402794
# Dorian Finney-Smith 0.8981216538126572
# Andrew Nembhard 0.8977836520320982
# Eric Gordon 0.8973897734117117
# Mason Plumlee 0.8973508081469129
# Chris Boucher 0.8967344967987744
# Jonathan Kuminga 0.8965392159805904
# Gary Trent Jr. 0.8962238952463538
# Tyus Jones 0.8943537675414622
# Reggie Bullock 0.8940227635498835
# Grayson Allen 0.8937880251845057
# Donte DiVincenzo 0.8937644846983295
# Al Horford 0.8931580817188184
# Kyle Lowry 0.8926113985145467
# Josh Okogie 0.8919625906107171
# Jevon Carter 0.8911468336308512
# Chris Paul 0.8908066908153972
# Coby White 0.8900836286049415
# Mike Conley 0.8896320706279066
# Nicolas Batum 0.8871783643118137
# Onyeka Okongwu 0.8864013056007722
# Austin Reaves 0.8860936581925745
# Marcus Smart 0.8853804567733516
# Andrew Wiggins 0.8851767117450324
# Jaylen Nowell 0.8847757955170543
# Bogdan Bogdanovic 0.8837664663116885
# Killian Hayes 0.882572264598588
# Cedi Osman 0.8820420115597393
# Josh Richardson 0.8814614974718654
# Patrick Beverley 0.8812872648905189
# Keita Bates-Diop 0.8811393226529363
# Devin Vassell 0.8802181199007997
# Monte Morris 0.8800802850113391
# Herbert Jones 0.8799995895118955
# Kentavious Caldwell-Pope 0.8789685898399943
# Pat Connaughton 0.8783015877042799
# Myles Turner 0.8781348835567315
# De'Anthony Melton 0.8777372965162696
# T.J. McConnell 0.8769390456758649
# Jalen Smith 0.8758536883201536
# Jalen Suggs 0.8757582578990117
# Isaiah Stewart 0.8742631736931474
# Zion Williamson 0.8740858822322919
# Rui Hachimura 0.8739015488122589
# Troy Brown Jr. 0.8733615073666537
# Isaiah Hartenstein 0.8727307522396258
# Precious Achiuwa 0.8717601745514474
# Rudy Gobert 0.8717167420365386
# Reggie Jackson 0.8702120242074088
# Dennis Smith Jr. 0.8701694363151814
# Larry Nance Jr. 0.8699068113023414
# Malaki Branham 0.8690041927266836
# Devonte' Graham 0.8687488081276327
# Corey Kispert 0.8684362555834156
# Isaiah Joe 0.86757161487591
# Bones Hyland 0.8673011146685111
# Gabe Vincent 0.867191825001341
# Jalen Johnson 0.8667066467617288
# Bol Bol 0.8659659828387282
# Kevon Looney 0.8645704131927803
# Moritz Wagner 0.8644906391425404
# Jordan Goodwin 0.8639547912578583
# Jose Alvarado 0.863697415358257
# Cameron Johnson 0.8617986366689415
# Tre Mann 0.8604184625162182
# Trey Lyles 0.8601661959458667
# Xavier Tillman 0.8597187489918204
# Kenrich Williams 0.8588278405805824
# Shake Milton 0.8586283494196838
# Alec Burks 0.8580682878383219
# David Roddy 0.8579983188170823
# Joe Harris 0.8577343244225221
# Clint Capela 0.8569430773605924
# Isaac Okoro 0.8566546592583848
# John Konchar 0.8562088462106
# Jalen Duren 0.8558825363239186
# Hamidou Diallo 0.8547998775089832
# Brandon Clarke 0.8516840745493341
# Victor Oladipo 0.8516251136831825
# Josh Green 0.8475536858632133
# Sam Hauser 0.845820531029282
# Kevin Love 0.8455566447850188
# Karl-Anthony Towns 0.8451852944606909
# Georges Niang 0.8446400808843273
# Ivica Zubac 0.844343051497412
# Jordan Nwora 0.8431046824497501
# Trendon Watford 0.842442681925669
# AJ Griffin 0.8419351727350664
# Jaren Jackson Jr. 0.840987739494636
# Drew Eubanks 0.8408365805477535
# Terrence Ross 0.840684401177134
# Oshae Brissett 0.8402619941675307
# Cameron Payne 0.8394104274333751
# Damion Lee 0.8385719277970497
# Davion Mitchell 0.8376480113357389
# Brook Lopez 0.8370415889184378
# Alex Caruso 0.836363977532344
# Collin Sexton 0.8359391388469665
# Aaron Wiggins 0.8350169599494297
# Anthony Lamb 0.8327967788439669
# Marvin Bagley III 0.8311489581991277
# Lonnie Walker IV 0.829661572078443
# Delon Wright 0.8296027504269807
# Dyson Daniels 0.8290316905663041
# Christian Braun 0.8290025429273766
# Jock Landale 0.8284351490485695
# John Wall 0.826765175043197
# Daniel Gafford 0.8251906566128662
# Usman Garuba 0.8242247158396485
# Cory Joseph 0.8241537764090641
# Andre Drummond 0.8239206618405504
# Terence Davis 0.8237291764204837
# Obi Toppin 0.8227386851369813
# Thomas Bryant 0.8216051550592743
# Ben Simmons 0.8213054523832554
# Doug McDermott 0.8193441251140726
# Wenyen Gabriel 0.8181875984661556
# Dwight Powell 0.8169543647148324
# Nickeil Alexander-Walker 0.8140806295081812
# P.J. Tucker 0.8139963200223927
# Haywood Highsmith 0.8138292837816732
# Khris Middleton 0.8129670091696045
# Will Barton 0.8127471971734237
# Isaiah Jackson 0.8125852860046513
# Taurean Prince 0.8121385913337992
# Lamar Stevens 0.8117991197112
# Jaylin Williams 0.8115972079035252
# Seth Curry 0.8102181911625316
# Steven Adams 0.80892775569364
# Kendrick Nunn 0.8069863826221118
# Paul Reed 0.804433248097425
# Jeff Green 0.8041638906001951
# Luke Kennard 0.8038531698329158
# Robert Covington 0.8037086986902571
# Kevin Knox II 0.8030201308283466
# Theo Maledon 0.8020563915203964
# Matisse Thybulle 0.8011741455409743
# Cam Thomas 0.8007583237295727
# Nic Claxton 0.7998946202925405
# Daishen Nix 0.7995507182978916
# JaMychal Green 0.7983883488865636
# James Wiseman 0.7949295125626394
# Josh Christopher 0.7947888076202335
# Thaddeus Young 0.7940194674162705
# Mike Muscala 0.793715245207798
# Aleksej Pokusevski 0.7929333352601277
# Derrick Jones Jr. 0.7915025928620385
# Joe Ingles 0.7914272392056446
# Ochai Agbaji 0.7912429862090014
# Nassir Little 0.7910650374899081
# Cam Reddish 0.7907704574425595
# Dario Saric 0.7905447457208413
# Isaiah Livers 0.7899462604653095
# Mo Bamba 0.7882062246038803
# Justise Winslow 0.788187313850341
# Gary Harris 0.787084566344276
# Mitchell Robinson 0.7866712186628328
# Mark Williams 0.7853959999599959
# JT Thor 0.784267296437159
# Ish Wainright 0.7841989658909142
# Sandro Mamukelashvili 0.7822000756161408
# Chris Duarte 0.7809291612575814
# Romeo Langford 0.7805321862210655
# Chimezie Metu 0.7801668737492959
# Dean Wade 0.7800683205067468
# Goran Dragic 0.7791296639067058
# Jeremiah Robinson-Earl 0.7760835230442432
# Yuta Watanabe 0.7748438457591306
# Jae'Sean Tate 0.7734329431158422
# Miles McBride 0.7729744261322036
# Rudy Gay 0.7722939857146953
# Eugene Omoruyi 0.7722048387731919
# Darius Bazley 0.7708175531405268
# R.J. Hampton 0.768955959752174
# Edmond Sumner 0.7682161410622546
# Blake Wesley 0.764767945875244
# Jaden Hardy 0.764503700456822
# T.J. Warren 0.7623787555381993
# Aaron Holiday 0.7613392326179877
# Landry Shamet 0.7605100706266091
# MarJon Beauchamp 0.7603968960312448
# Kris Dunn 0.7596704145591192
# Walker Kessler 0.7593647908418087
# Austin Rivers 0.7591043457183629
# George Hill 0.7581242697968121
# Moses Moody 0.7572614880542393
# Vlatko Cancar 0.7563782786664639
# Willy Hernangomez 0.7561633754089554
# Zeke Nnaji 0.752042402484337
# Christian Koloko 0.7516668790763428
# Ty Jerome 0.7511267655122705
# Simone Fontecchio 0.7483547069616517
# Isaiah Roby 0.747931670277618
# Maxi Kleber 0.7476633163897758
# Malachi Flynn 0.7474226493897701
# Jordan McLaughlin 0.7468340541053377
# Ricky Rubio 0.7466078681826713
# Justin Holiday 0.7437550333263472
# Blake Griffin 0.7408342245674242
# Ousmane Dieng 0.7403960292306905
# Bryce McGowens 0.7402616148364358
# Jaxson Hayes 0.7399852187466516
# Robert Williams III 0.7373268067498101
# Luke Kornet 0.7372725973454947
# Payton Pritchard 0.7370476969889435
# Montrezl Harrell 0.7368112886268293
# Danuel House Jr. 0.7356702857948011
# Goga Bitadze 0.7354983780034295
# Charles Bassey 0.7352632131928946
# Day'Ron Sharpe 0.7331539933620546
# Jabari Walker 0.7318523814806646
# Juancho Hernangomez 0.7317255136055612
# Keon Johnson 0.7276796254203206
# Juan Toscano-Anderson 0.7276443754867186
# Nick Richards 0.7270127433039542
# James Bouknight 0.7264697446703469
# Wesley Matthews 0.7263284490589823
# Garrison Mathews 0.7227783504244505
# Dewayne Dedmon 0.7227643539374391
# Frank Ntilikina 0.7214406394388043
# TyTy Washington Jr. 0.7207788468056754
# Chuma Okeke 0.7201449142343366
# Johnny Davis 0.719188120010905
# Javonte Green 0.7181234517705819
# Cade Cunningham 0.7167473052354999
# Ziaire Williams 0.7165245006459896
# Kai Jones 0.7160055883621841
# Ish Smith 0.7139582875036798
# Lindy Waters III 0.7121692573589058
# Svi Mykhailiuk 0.7117897164300042
# Taj Gibson 0.7106271728440388
# Patty Mills 0.7095214920500064
# Stanley Johnson 0.7094846007386227
# Duncan Robinson 0.7090350064992683
# Bismack Biyombo 0.7070841751749715
# Caleb Houstan 0.7068743702761877
# Saben Lee 0.7064801880608617
# Duane Washington Jr. 0.7052313014705427
# Dalano Banton 0.696197355403456
# Rodney McGruder 0.695365041332261
# Gorgui Dieng 0.6927821231033298
# Kevon Harris 0.6927620167356673
# Anthony Gill 0.6925885514227048
# Raul Neto 0.6911991462808165
# Evan Fournier 0.6889530954049966
# Amir Coffey 0.6879593083789557
# Kennedy Chandler 0.6864819412068199
# Jericho Sims 0.6849720055903405
# Kessler Edwards 0.6839257523886658
# Davis Bertans 0.6839146409438612
# Davon Reed 0.6825941434937827
# Bruno Fernando 0.6797765384706919
# McKinley Wright IV 0.6753669249929855
# Jake LaRavia 0.674013346165307
# Gary Payton II 0.6736633077738754
# Jae Crowder 0.67170173116782
# Orlando Robinson 0.6716606285301489
# Admiral Schofield 0.6683454037532573
# Furkan Korkmaz 0.6682614014527007
# Max Christie 0.6669420901704407
# JaVale McGee 0.6664123221832146
# Dalen Terry 0.6641034914757946
# Julian Champagnie 0.6621647799306027
# Derrick Rose 0.6621146436204023
# Nathan Knight 0.6620477245212806
# Damian Jones 0.6610498917690102
# Markieff Morris 0.6601377004291302
# Dominick Barlow 0.6592187144622775
# Luka Garza 0.6582562953670549
# Theo Pinson 0.6565002347498524
# Johnny Juzang 0.6563469711551728
# Brandon Boston Jr. 0.6559764416903398
# Patrick Baldwin Jr. 0.6538147895528916
# Jonathan Isaac 0.6510908706846935
# Jamal Cain 0.6505675630137392
# Kira Lewis Jr. 0.6485748248915989
# Jeff Dowtin Jr. 0.6469926887854023
# Kenneth Lofton Jr. 0.6458315054936059
# Frank Kaminsky 0.6456515235500361
# Nerlens Noel 0.6450856145570066
# Shaquille Harrison 0.6449664600388204
# AJ Green 0.6445692701396643
# Matthew Dellavedova 0.6397540225027847
# Matt Ryan 0.6378932168102464
# James Johnson 0.6377481206014606
# David Duke Jr. 0.6369878576285037
# Luka Samanic 0.63627160063583
# Skylar Mays 0.6339072902733108
# Terry Taylor 0.6314832190109432
# John Butler Jr. 0.6302855220391567
# KZ Okpala 0.6302594408909024
# Richaun Holmes 0.6288772029542475
# Vit Krejci 0.6275542952562515
# Garrett Temple 0.626745263970981
# Nikola Jovic 0.6257021883041567
# Robin Lopez 0.6251145339638763
# Serge Ibaka 0.6250844663176516
# Moses Brown 0.6247252685034063
# Dru Smith 0.6239455929129212
# Justin Jackson 0.6239424312628845
# Cody Martin 0.6226997952049637
# Otto Porter Jr. 0.6214244416461638
# Bryn Forbes 0.6213038706650311
# Moussa Diabate 0.6210767622592387
# Trent Forrest 0.6192454816889725
# Wendell Moore Jr. 0.6190806419340096
# Jarrett Culver 0.618565598704899
# Mamadi Diakite 0.618250568383336
# Kemba Walker 0.6182240223212719
# Jaden Springer 0.6172245903009251
# Peyton Watson 0.6158078554423321
# Danny Green 0.6133380786112108
# Josh Minott 0.6117842885219043
# Facundo Campazzo 0.6106446849269258
# Greg Brown III 0.6094602647981416
# Noah Vonleh 0.6085223184312772
# Meyers Leonard 0.6076225808112572
# Khem Birch 0.6072066598554013
# Jay Huff 0.60666680761077
# Jared Rhoden 0.6066309360953345
# Jack White 0.605212821790878
# Isaiah Mobley 0.603818902910565
# Joshua Primo 0.6031577008563194
# Alex Len 0.6020721176903472
# Andre Iguodala 0.6008988784958736
# Lindell Wigginton 0.6007886204909197
# Omer Yurtseven 0.6001621994860351
# Thanasis Antetokounmpo 0.5997690724952682
# Quenton Jackson 0.5991188925697244
# Olivier Sarr 0.5977006360074678
# Jeenathan Williams 0.5974356474271917
# Daniel Theis 0.597157858869197
# Cody Zeller 0.5970877997101528
# JD Davison 0.5957641486131239
# Jordan Hall 0.5949515826869813
# Udonis Haslem 0.5948088166205605
# Sam Merrill 0.594699339307391
# Boban Marjanovic 0.5944044924231989
# Jamaree Bouyea 0.5919247665735027
# Scotty Pippen Jr. 0.5917781085555723
# RaiQuan Gray 0.589527866927003
# DeAndre Jordan 0.5895186759839538
# Gabe York 0.5892431087609106
# Jarrell Brantley 0.58905665983535
# Michael Carter-Williams 0.5885392683759713
# Mac McClung 0.5883097697724877
# Ron Harper Jr. 0.5880959627598392
# Ryan Rollins 0.5877830809615389
# Vince Williams Jr. 0.5864967134030616
# Xavier Sneed 0.5860215502079932
# Tony Bradley 0.5843463811091848
# Keon Ellis 0.5839886811290346
# Marko Simonovic 0.5832160711891349
# Darius Days 0.5827619665856028
# Carlik Jones 0.5780335280288112
# Tyrese Martin 0.5756129563959635
# Lester Quinones 0.573324362193548
# Trevelin Queen 0.5705959111729468
# Trevor Hudgins 0.5599304509190035
# Buddy Boeheim 0.5563022980263393
# Kobi Simmons 0.5505164008981229
# Mfiondu Kabengele 0.5435105216202948
# Xavier Cooks 0.5428415253771274
# Udoka Azubuike 0.5424795130399411
# Isaiah Todd 0.5423318168398258
# Vernon Carey Jr. 0.5421266692915048
# Alize Johnson 0.5365280194559305
# Kendall Brown 0.5340884461789718
# Braxton Key 0.5253857316983725
# A.J. Lawson 0.519765454602505
# Stanley Umude 0.48372881914965077
# Jay Scrubb 0.4784581864118813
# Sterling Brown 0.4725089750242659
# Frank Jackson 0.4555762961982261
# Chance Comanche 0.4318682256432544
# PJ Dozier 0.4072938788873658
# Jason Preston 0.38936039345856244
# Ryan Arcidiacono 0.38759668678127335
# Justin Minaya 0.3781089481070862
# Alondes Williams 0.374744620328031
# Jared Butler 0.36125932967890156
# Leandro Bolmaro 0.3591035141216132
# Devon Dotson 0.35276094228929045
# Justin Champagnie 0.3510470743156041
# Jacob Gilyard 0.3507752575166464
# Micah Potter 0.3452210675645893
# Louis King 0.33971969711964806
# Joe Wieskamp 0.3343389692356859
# Xavier Moon 0.33404766739756614
# Cole Swider 0.33351030499340306
# Dylan Windler 0.33256016242587594
# Malcolm Hill 0.33092666828817574
# Tyler Dorsey 0.32945662194290404
# Trevor Keels 0.32848775076911335
# Jordan Schakel 0.2963411358769732
# Neemias Queta 0.27545533101085906
# Donovan Williams 0.2662565346965434
# Dereon Seabron 0.26529632538857284
# Chima Moneke 0.265058799228129
# Chris Silva 0.26231685925206527
# Michael Foster Jr. 0.0
# Deonte Burton 0.0

# %%
# Define threshold values
thresholds = [0.9, 0.8, 0.7]

# Initialize dictionaries to store clusters for each threshold
clusters = {threshold: {} for threshold in thresholds}

# Iterate through similarity scores and group players into clusters for each threshold
for player, score in similar_players_dict.items():
    for threshold in thresholds:
        if score >= threshold:
            if score in clusters[threshold]:
                clusters[threshold][score].append(player)
            else:
                clusters[threshold][score] = [player]

# Display clusters
print("Clusters of players similar to Jayson Tatum:")
for threshold in thresholds:
    print(f"\nClusters with similarity score threshold >= {threshold}:")
    for score, players in clusters[threshold].items():
        print(f"  Cluster with similarity score {score}: {players}")
# Out:
# Clusters of players similar to Jayson Tatum:
#
# Clusters with similarity score threshold >= 0.9:
#   Cluster with similarity score 0.9927205049819267: ['Paolo Banchero']
#   Cluster with similarity score 0.9910677514947449: ['Pascal Siakam']
#   Cluster with similarity score 0.9907218723481154: ['Jaylen Brown']
#   Cluster with similarity score 0.9840968108491313: ['LeBron James']
#   Cluster with similarity score 0.9840660311593127: ['Julius Randle']
#   Cluster with similarity score 0.9838843115420738: ['Luka Doncic']
#   Cluster with similarity score 0.9832716949276415: ['Giannis Antetokounmpo']
#   Cluster with similarity score 0.9809920586076716: ['Joel Embiid']
#   Cluster with similarity score 0.9807495578806485: ['Zach LaVine']
#   Cluster with similarity score 0.9793078379574752: ['DeMar DeRozan']
#   Cluster with similarity score 0.9783934684394806: ['Kyle Kuzma']
#   Cluster with similarity score 0.9773317608518364: ['Jalen Green']
#   Cluster with similarity score 0.9747468331224342: ['Mikal Bridges']
#   Cluster with similarity score 0.9729858514286286: ['CJ McCollum']
#   Cluster with similarity score 0.9719739601535338: ['Kyrie Irving']
#   Cluster with similarity score 0.9710785685974892: ['Shai Gilgeous-Alexander']
#   Cluster with similarity score 0.9696479653771177: ['Lauri Markkanen']
#   Cluster with similarity score 0.9696454241110796: ['Franz Wagner']
#   Cluster with similarity score 0.969467571275337: ["De'Aaron Fox"]
#   Cluster with similarity score 0.9690689388582499: ['RJ Barrett']
#   Cluster with similarity score 0.9689780192583851: ['Bam Adebayo']
#   Cluster with similarity score 0.9685086241208964: ['Keldon Johnson']
#   Cluster with similarity score 0.9683709835127601: ['Anthony Edwards']
#   Cluster with similarity score 0.9681589612801281: ['Donovan Mitchell']
#   Cluster with similarity score 0.9674250678742424: ['Scottie Barnes']
#   Cluster with similarity score 0.9665951778845921: ['Stephen Curry']
#   Cluster with similarity score 0.965208388106513: ['Ja Morant']
#   Cluster with similarity score 0.9649152864212112: ['Josh Giddey']
#   Cluster with similarity score 0.9640609265748883: ['Nikola Vucevic']
#   Cluster with similarity score 0.9629943254075546: ['Aaron Gordon']
#   Cluster with similarity score 0.9623792738644352: ['Kristaps Porzingis']
#   Cluster with similarity score 0.9623646004585733: ['Buddy Hield']
#   Cluster with similarity score 0.962059707704873: ['Jordan Poole']
#   Cluster with similarity score 0.9618915960235448: ['Paul George']
#   Cluster with similarity score 0.9603548132259798: ['Damian Lillard']
#   Cluster with similarity score 0.9595183907495739: ['Terry Rozier']
#   Cluster with similarity score 0.9589751388761512: ['Tyler Herro']
#   Cluster with similarity score 0.9589525601411693: ['Alperen Sengun']
#   Cluster with similarity score 0.957986402760583: ['Nikola Jokic']
#   Cluster with similarity score 0.9574639725638181: ['Klay Thompson']
#   Cluster with similarity score 0.9571715156420317: ['Immanuel Quickley']
#   Cluster with similarity score 0.9571331852519553: ['Jaden Ivey']
#   Cluster with similarity score 0.9564178007575057: ['Devin Booker']
#   Cluster with similarity score 0.9553523743861392: ['P.J. Washington']
#   Cluster with similarity score 0.9553059133657921: ['Jalen Brunson']
#   Cluster with similarity score 0.9543032098313154: ['Kawhi Leonard']
#   Cluster with similarity score 0.9531905844279467: ['Bennedict Mathurin']
#   Cluster with similarity score 0.9530722194870402: ['Tobias Harris']
#   Cluster with similarity score 0.9528662194152248: ['Dejounte Murray']
#   Cluster with similarity score 0.9525592560850035: ['Jerami Grant']
#   Cluster with similarity score 0.9514529322760054: ['Desmond Bane']
#   Cluster with similarity score 0.9502464954638618: ['Harrison Barnes']
#   Cluster with similarity score 0.9501790517784667: ['Kevin Porter Jr.']
#   Cluster with similarity score 0.9500300184695158: ['Luguentz Dort']
#   Cluster with similarity score 0.9485642321197982: ['Jimmy Butler']
#   Cluster with similarity score 0.9485491654409423: ['Jamal Murray']
#   Cluster with similarity score 0.9479048800252805: ['Jrue Holiday']
#   Cluster with similarity score 0.9468639966468269: ['Kenyon Martin Jr.']
#   Cluster with similarity score 0.9459988409398602: ['Domantas Sabonis']
#   Cluster with similarity score 0.9458097983356276: ['Dillon Brooks']
#   Cluster with similarity score 0.945417134398848: ['Anthony Davis']
#   Cluster with similarity score 0.9444732345570522: ['Kevin Huerter']
#   Cluster with similarity score 0.9435416493948299: ['Spencer Dinwiddie']
#   Cluster with similarity score 0.943491496926229: ['Jordan Clarkson']
#   Cluster with similarity score 0.9418296584427431: ['Deandre Ayton']
#   Cluster with similarity score 0.940667583946705: ['Russell Westbrook']
#   Cluster with similarity score 0.9404739207443152: ['Keegan Murray']
#   Cluster with similarity score 0.9392749046578394: ["D'Angelo Russell"]
#   Cluster with similarity score 0.9392336846712848: ['Saddiq Bey']
#   Cluster with similarity score 0.9390734380901319: ['Malik Beasley']
#   Cluster with similarity score 0.9387476628175023: ['Jabari Smith Jr.']
#   Cluster with similarity score 0.9383802582222143: ['Caris LeVert']
#   Cluster with similarity score 0.9380170451504646: ['Kevin Durant']
#   Cluster with similarity score 0.9375890308897896: ['Kelly Olynyk']
#   Cluster with similarity score 0.9368976583755232: ['Deni Avdija']
#   Cluster with similarity score 0.9365724003222996: ['Bruce Brown']
#   Cluster with similarity score 0.9353050300888102: ['Evan Mobley']
#   Cluster with similarity score 0.9346478620366613: ['Tim Hardaway Jr.']
#   Cluster with similarity score 0.9343374971927173: ['Bradley Beal']
#   Cluster with similarity score 0.9336423269682974: ['Christian Wood']
#   Cluster with similarity score 0.9326706331723691: ['Derrick White']
#   Cluster with similarity score 0.9325371432310843: ['Jalen Williams']
#   Cluster with similarity score 0.9291186980458868: ["Royce O'Neale"]
#   Cluster with similarity score 0.9268673817966834: ['Anfernee Simons']
#   Cluster with similarity score 0.92634533210595: ['James Harden']
#   Cluster with similarity score 0.925830145842022: ['Trey Murphy III']
#   Cluster with similarity score 0.9254444181158504: ['Malcolm Brogdon']
#   Cluster with similarity score 0.9251396000489099: ['Wendell Carter Jr.']
#   Cluster with similarity score 0.9250700207178181: ['Michael Porter Jr.']
#   Cluster with similarity score 0.924891609113557: ['Jaden McDaniels']
#   Cluster with similarity score 0.9247493506414161: ['Josh Hart']
#   Cluster with similarity score 0.9247473286132672: ['Malik Monk']
#   Cluster with similarity score 0.9247255016838724: ['Darius Garland']
#   Cluster with similarity score 0.9240233544747254: ['Tyrese Maxey']
#   Cluster with similarity score 0.9233288161472052: ['John Collins']
#   Cluster with similarity score 0.9229533384278362: ['Jusuf Nurkic']
#   Cluster with similarity score 0.9225258630484511: ['Brandon Ingram']
#   Cluster with similarity score 0.9216679256003089: ['Fred VanVleet']
#   Cluster with similarity score 0.9206430561145371: ['Kelly Oubre Jr.']
#   Cluster with similarity score 0.9202194755758708: ["De'Andre Hunter"]
#   Cluster with similarity score 0.9181066018867775: ['Bobby Portis']
#   Cluster with similarity score 0.9176205322377388: ['Bojan Bogdanovic']
#   Cluster with similarity score 0.9173442892639628: ['Zach Collins']
#   Cluster with similarity score 0.9172826593799128: ['Max Strus']
#   Cluster with similarity score 0.9158935899891545: ['Naji Marshall']
#   Cluster with similarity score 0.9149334946039943: ['Jeremy Sochan']
#   Cluster with similarity score 0.9136694514075273: ['Talen Horton-Tucker']
#   Cluster with similarity score 0.9135284763406564: ['Trae Young']
#   Cluster with similarity score 0.9128843323914769: ['Santi Aldama']
#   Cluster with similarity score 0.9120996449340145: ['LaMelo Ball']
#   Cluster with similarity score 0.9116658956123587: ['Jalen McDaniels']
#   Cluster with similarity score 0.9115363377036844: ['Markelle Fultz']
#   Cluster with similarity score 0.9110170918242494: ['Naz Reid']
#   Cluster with similarity score 0.910921696113231: ['Jonas Valanciunas']
#   Cluster with similarity score 0.9097178739948597: ['Norman Powell']
#   Cluster with similarity score 0.9095951453509445: ['Quentin Grimes']
#   Cluster with similarity score 0.9095193182043224: ['Jarrett Allen']
#   Cluster with similarity score 0.9093689329267086: ['Kyle Anderson']
#   Cluster with similarity score 0.9093342487192593: ['Tari Eason']
#   Cluster with similarity score 0.9083895838499836: ['Caleb Martin']
#   Cluster with similarity score 0.9079184667475383: ['Patrick Williams']
#   Cluster with similarity score 0.90765499383358: ['Jarred Vanderbilt']
#   Cluster with similarity score 0.9074457857473901: ['Shaedon Sharpe']
#   Cluster with similarity score 0.907178777648903: ['Cole Anthony']
#   Cluster with similarity score 0.9055257782318733: ['Grant Williams']
#   Cluster with similarity score 0.9046220442745293: ['Marcus Morris Sr.']
#   Cluster with similarity score 0.9044958913960142: ['Aaron Nesmith']
#   Cluster with similarity score 0.9044267671819926: ['Tyrese Haliburton']
#   Cluster with similarity score 0.903205754001861: ['Terance Mann']
#   Cluster with similarity score 0.9031734946957156: ['Torrey Craig']
#   Cluster with similarity score 0.9028758655467822: ['Ayo Dosunmu']
#   Cluster with similarity score 0.9027339162196746: ['O.G. Anunoby']
#   Cluster with similarity score 0.9015958647189855: ['Draymond Green']
#   Cluster with similarity score 0.9009970364964439: ['Tre Jones']
#   Cluster with similarity score 0.9009536673494101: ['Dennis Schroder']
#
# Clusters with similarity score threshold >= 0.8:
#   Cluster with similarity score 0.9927205049819267: ['Paolo Banchero']
#   Cluster with similarity score 0.9910677514947449: ['Pascal Siakam']
#   Cluster with similarity score 0.9907218723481154: ['Jaylen Brown']
#   Cluster with similarity score 0.9840968108491313: ['LeBron James']
#   Cluster with similarity score 0.9840660311593127: ['Julius Randle']
#   Cluster with similarity score 0.9838843115420738: ['Luka Doncic']
#   Cluster with similarity score 0.9832716949276415: ['Giannis Antetokounmpo']
#   Cluster with similarity score 0.9809920586076716: ['Joel Embiid']
#   Cluster with similarity score 0.9807495578806485: ['Zach LaVine']
#   Cluster with similarity score 0.9793078379574752: ['DeMar DeRozan']
#   Cluster with similarity score 0.9783934684394806: ['Kyle Kuzma']
#   Cluster with similarity score 0.9773317608518364: ['Jalen Green']
#   Cluster with similarity score 0.9747468331224342: ['Mikal Bridges']
#   Cluster with similarity score 0.9729858514286286: ['CJ McCollum']
#   Cluster with similarity score 0.9719739601535338: ['Kyrie Irving']
#   Cluster with similarity score 0.9710785685974892: ['Shai Gilgeous-Alexander']
#   Cluster with similarity score 0.9696479653771177: ['Lauri Markkanen']
#   Cluster with similarity score 0.9696454241110796: ['Franz Wagner']
#   Cluster with similarity score 0.969467571275337: ["De'Aaron Fox"]
#   Cluster with similarity score 0.9690689388582499: ['RJ Barrett']
#   Cluster with similarity score 0.9689780192583851: ['Bam Adebayo']
#   Cluster with similarity score 0.9685086241208964: ['Keldon Johnson']
#   Cluster with similarity score 0.9683709835127601: ['Anthony Edwards']
#   Cluster with similarity score 0.9681589612801281: ['Donovan Mitchell']
#   Cluster with similarity score 0.9674250678742424: ['Scottie Barnes']
#   Cluster with similarity score 0.9665951778845921: ['Stephen Curry']
#   Cluster with similarity score 0.965208388106513: ['Ja Morant']
#   Cluster with similarity score 0.9649152864212112: ['Josh Giddey']
#   Cluster with similarity score 0.9640609265748883: ['Nikola Vucevic']
#   Cluster with similarity score 0.9629943254075546: ['Aaron Gordon']
#   Cluster with similarity score 0.9623792738644352: ['Kristaps Porzingis']
#   Cluster with similarity score 0.9623646004585733: ['Buddy Hield']
#   Cluster with similarity score 0.962059707704873: ['Jordan Poole']
#   Cluster with similarity score 0.9618915960235448: ['Paul George']
#   Cluster with similarity score 0.9603548132259798: ['Damian Lillard']
#   Cluster with similarity score 0.9595183907495739: ['Terry Rozier']
#   Cluster with similarity score 0.9589751388761512: ['Tyler Herro']
#   Cluster with similarity score 0.9589525601411693: ['Alperen Sengun']
#   Cluster with similarity score 0.957986402760583: ['Nikola Jokic']
#   Cluster with similarity score 0.9574639725638181: ['Klay Thompson']
#   Cluster with similarity score 0.9571715156420317: ['Immanuel Quickley']
#   Cluster with similarity score 0.9571331852519553: ['Jaden Ivey']
#   Cluster with similarity score 0.9564178007575057: ['Devin Booker']
#   Cluster with similarity score 0.9553523743861392: ['P.J. Washington']
#   Cluster with similarity score 0.9553059133657921: ['Jalen Brunson']
#   Cluster with similarity score 0.9543032098313154: ['Kawhi Leonard']
#   Cluster with similarity score 0.9531905844279467: ['Bennedict Mathurin']
#   Cluster with similarity score 0.9530722194870402: ['Tobias Harris']
#   Cluster with similarity score 0.9528662194152248: ['Dejounte Murray']
#   Cluster with similarity score 0.9525592560850035: ['Jerami Grant']
#   Cluster with similarity score 0.9514529322760054: ['Desmond Bane']
#   Cluster with similarity score 0.9502464954638618: ['Harrison Barnes']
#   Cluster with similarity score 0.9501790517784667: ['Kevin Porter Jr.']
#   Cluster with similarity score 0.9500300184695158: ['Luguentz Dort']
#   Cluster with similarity score 0.9485642321197982: ['Jimmy Butler']
#   Cluster with similarity score 0.9485491654409423: ['Jamal Murray']
#   Cluster with similarity score 0.9479048800252805: ['Jrue Holiday']
#   Cluster with similarity score 0.9468639966468269: ['Kenyon Martin Jr.']
#   Cluster with similarity score 0.9459988409398602: ['Domantas Sabonis']
#   Cluster with similarity score 0.9458097983356276: ['Dillon Brooks']
#   Cluster with similarity score 0.945417134398848: ['Anthony Davis']
#   Cluster with similarity score 0.9444732345570522: ['Kevin Huerter']
#   Cluster with similarity score 0.9435416493948299: ['Spencer Dinwiddie']
#   Cluster with similarity score 0.943491496926229: ['Jordan Clarkson']
#   Cluster with similarity score 0.9418296584427431: ['Deandre Ayton']
#   Cluster with similarity score 0.940667583946705: ['Russell Westbrook']
#   Cluster with similarity score 0.9404739207443152: ['Keegan Murray']
#   Cluster with similarity score 0.9392749046578394: ["D'Angelo Russell"]
#   Cluster with similarity score 0.9392336846712848: ['Saddiq Bey']
#   Cluster with similarity score 0.9390734380901319: ['Malik Beasley']
#   Cluster with similarity score 0.9387476628175023: ['Jabari Smith Jr.']
#   Cluster with similarity score 0.9383802582222143: ['Caris LeVert']
#   Cluster with similarity score 0.9380170451504646: ['Kevin Durant']
#   Cluster with similarity score 0.9375890308897896: ['Kelly Olynyk']
#   Cluster with similarity score 0.9368976583755232: ['Deni Avdija']
#   Cluster with similarity score 0.9365724003222996: ['Bruce Brown']
#   Cluster with similarity score 0.9353050300888102: ['Evan Mobley']
#   Cluster with similarity score 0.9346478620366613: ['Tim Hardaway Jr.']
#   Cluster with similarity score 0.9343374971927173: ['Bradley Beal']
#   Cluster with similarity score 0.9336423269682974: ['Christian Wood']
#   Cluster with similarity score 0.9326706331723691: ['Derrick White']
#   Cluster with similarity score 0.9325371432310843: ['Jalen Williams']
#   Cluster with similarity score 0.9291186980458868: ["Royce O'Neale"]
#   Cluster with similarity score 0.9268673817966834: ['Anfernee Simons']
#   Cluster with similarity score 0.92634533210595: ['James Harden']
#   Cluster with similarity score 0.925830145842022: ['Trey Murphy III']
#   Cluster with similarity score 0.9254444181158504: ['Malcolm Brogdon']
#   Cluster with similarity score 0.9251396000489099: ['Wendell Carter Jr.']
#   Cluster with similarity score 0.9250700207178181: ['Michael Porter Jr.']
#   Cluster with similarity score 0.924891609113557: ['Jaden McDaniels']
#   Cluster with similarity score 0.9247493506414161: ['Josh Hart']
#   Cluster with similarity score 0.9247473286132672: ['Malik Monk']
#   Cluster with similarity score 0.9247255016838724: ['Darius Garland']
#   Cluster with similarity score 0.9240233544747254: ['Tyrese Maxey']
#   Cluster with similarity score 0.9233288161472052: ['John Collins']
#   Cluster with similarity score 0.9229533384278362: ['Jusuf Nurkic']
#   Cluster with similarity score 0.9225258630484511: ['Brandon Ingram']
#   Cluster with similarity score 0.9216679256003089: ['Fred VanVleet']
#   Cluster with similarity score 0.9206430561145371: ['Kelly Oubre Jr.']
#   Cluster with similarity score 0.9202194755758708: ["De'Andre Hunter"]
#   Cluster with similarity score 0.9181066018867775: ['Bobby Portis']
#   Cluster with similarity score 0.9176205322377388: ['Bojan Bogdanovic']
#   Cluster with similarity score 0.9173442892639628: ['Zach Collins']
#   Cluster with similarity score 0.9172826593799128: ['Max Strus']
#   Cluster with similarity score 0.9158935899891545: ['Naji Marshall']
#   Cluster with similarity score 0.9149334946039943: ['Jeremy Sochan']
#   Cluster with similarity score 0.9136694514075273: ['Talen Horton-Tucker']
#   Cluster with similarity score 0.9135284763406564: ['Trae Young']
#   Cluster with similarity score 0.9128843323914769: ['Santi Aldama']
#   Cluster with similarity score 0.9120996449340145: ['LaMelo Ball']
#   Cluster with similarity score 0.9116658956123587: ['Jalen McDaniels']
#   Cluster with similarity score 0.9115363377036844: ['Markelle Fultz']
#   Cluster with similarity score 0.9110170918242494: ['Naz Reid']
#   Cluster with similarity score 0.910921696113231: ['Jonas Valanciunas']
#   Cluster with similarity score 0.9097178739948597: ['Norman Powell']
#   Cluster with similarity score 0.9095951453509445: ['Quentin Grimes']
#   Cluster with similarity score 0.9095193182043224: ['Jarrett Allen']
#   Cluster with similarity score 0.9093689329267086: ['Kyle Anderson']
#   Cluster with similarity score 0.9093342487192593: ['Tari Eason']
#   Cluster with similarity score 0.9083895838499836: ['Caleb Martin']
#   Cluster with similarity score 0.9079184667475383: ['Patrick Williams']
#   Cluster with similarity score 0.90765499383358: ['Jarred Vanderbilt']
#   Cluster with similarity score 0.9074457857473901: ['Shaedon Sharpe']
#   Cluster with similarity score 0.907178777648903: ['Cole Anthony']
#   Cluster with similarity score 0.9055257782318733: ['Grant Williams']
#   Cluster with similarity score 0.9046220442745293: ['Marcus Morris Sr.']
#   Cluster with similarity score 0.9044958913960142: ['Aaron Nesmith']
#   Cluster with similarity score 0.9044267671819926: ['Tyrese Haliburton']
#   Cluster with similarity score 0.903205754001861: ['Terance Mann']
#   Cluster with similarity score 0.9031734946957156: ['Torrey Craig']
#   Cluster with similarity score 0.9028758655467822: ['Ayo Dosunmu']
#   Cluster with similarity score 0.9027339162196746: ['O.G. Anunoby']
#   Cluster with similarity score 0.9015958647189855: ['Draymond Green']
#   Cluster with similarity score 0.9009970364964439: ['Tre Jones']
#   Cluster with similarity score 0.9009536673494101: ['Dennis Schroder']
#   Cluster with similarity score 0.8997776544326804: ['Jakob Poeltl']
#   Cluster with similarity score 0.89913610402794: ['Gordon Hayward']
#   Cluster with similarity score 0.8981216538126572: ['Dorian Finney-Smith']
#   Cluster with similarity score 0.8977836520320982: ['Andrew Nembhard']
#   Cluster with similarity score 0.8973897734117117: ['Eric Gordon']
#   Cluster with similarity score 0.8973508081469129: ['Mason Plumlee']
#   Cluster with similarity score 0.8967344967987744: ['Chris Boucher']
#   Cluster with similarity score 0.8965392159805904: ['Jonathan Kuminga']
#   Cluster with similarity score 0.8962238952463538: ['Gary Trent Jr.']
#   Cluster with similarity score 0.8943537675414622: ['Tyus Jones']
#   Cluster with similarity score 0.8940227635498835: ['Reggie Bullock']
#   Cluster with similarity score 0.8937880251845057: ['Grayson Allen']
#   Cluster with similarity score 0.8937644846983295: ['Donte DiVincenzo']
#   Cluster with similarity score 0.8931580817188184: ['Al Horford']
#   Cluster with similarity score 0.8926113985145467: ['Kyle Lowry']
#   Cluster with similarity score 0.8919625906107171: ['Josh Okogie']
#   Cluster with similarity score 0.8911468336308512: ['Jevon Carter']
#   Cluster with similarity score 0.8908066908153972: ['Chris Paul']
#   Cluster with similarity score 0.8900836286049415: ['Coby White']
#   Cluster with similarity score 0.8896320706279066: ['Mike Conley']
#   Cluster with similarity score 0.8871783643118137: ['Nicolas Batum']
#   Cluster with similarity score 0.8864013056007722: ['Onyeka Okongwu']
#   Cluster with similarity score 0.8860936581925745: ['Austin Reaves']
#   Cluster with similarity score 0.8853804567733516: ['Marcus Smart']
#   Cluster with similarity score 0.8851767117450324: ['Andrew Wiggins']
#   Cluster with similarity score 0.8847757955170543: ['Jaylen Nowell']
#   Cluster with similarity score 0.8837664663116885: ['Bogdan Bogdanovic']
#   Cluster with similarity score 0.882572264598588: ['Killian Hayes']
#   Cluster with similarity score 0.8820420115597393: ['Cedi Osman']
#   Cluster with similarity score 0.8814614974718654: ['Josh Richardson']
#   Cluster with similarity score 0.8812872648905189: ['Patrick Beverley']
#   Cluster with similarity score 0.8811393226529363: ['Keita Bates-Diop']
#   Cluster with similarity score 0.8802181199007997: ['Devin Vassell']
#   Cluster with similarity score 0.8800802850113391: ['Monte Morris']
#   Cluster with similarity score 0.8799995895118955: ['Herbert Jones']
#   Cluster with similarity score 0.8789685898399943: ['Kentavious Caldwell-Pope']
#   Cluster with similarity score 0.8783015877042799: ['Pat Connaughton']
#   Cluster with similarity score 0.8781348835567315: ['Myles Turner']
#   Cluster with similarity score 0.8777372965162696: ["De'Anthony Melton"]
#   Cluster with similarity score 0.8769390456758649: ['T.J. McConnell']
#   Cluster with similarity score 0.8758536883201536: ['Jalen Smith']
#   Cluster with similarity score 0.8757582578990117: ['Jalen Suggs']
#   Cluster with similarity score 0.8742631736931474: ['Isaiah Stewart']
#   Cluster with similarity score 0.8740858822322919: ['Zion Williamson']
#   Cluster with similarity score 0.8739015488122589: ['Rui Hachimura']
#   Cluster with similarity score 0.8733615073666537: ['Troy Brown Jr.']
#   Cluster with similarity score 0.8727307522396258: ['Isaiah Hartenstein']
#   Cluster with similarity score 0.8717601745514474: ['Precious Achiuwa']
#   Cluster with similarity score 0.8717167420365386: ['Rudy Gobert']
#   Cluster with similarity score 0.8702120242074088: ['Reggie Jackson']
#   Cluster with similarity score 0.8701694363151814: ['Dennis Smith Jr.']
#   Cluster with similarity score 0.8699068113023414: ['Larry Nance Jr.']
#   Cluster with similarity score 0.8690041927266836: ['Malaki Branham']
#   Cluster with similarity score 0.8687488081276327: ["Devonte' Graham"]
#   Cluster with similarity score 0.8684362555834156: ['Corey Kispert']
#   Cluster with similarity score 0.86757161487591: ['Isaiah Joe']
#   Cluster with similarity score 0.8673011146685111: ['Bones Hyland']
#   Cluster with similarity score 0.867191825001341: ['Gabe Vincent']
#   Cluster with similarity score 0.8667066467617288: ['Jalen Johnson']
#   Cluster with similarity score 0.8659659828387282: ['Bol Bol']
#   Cluster with similarity score 0.8645704131927803: ['Kevon Looney']
#   Cluster with similarity score 0.8644906391425404: ['Moritz Wagner']
#   Cluster with similarity score 0.8639547912578583: ['Jordan Goodwin']
#   Cluster with similarity score 0.863697415358257: ['Jose Alvarado']
#   Cluster with similarity score 0.8617986366689415: ['Cameron Johnson']
#   Cluster with similarity score 0.8604184625162182: ['Tre Mann']
#   Cluster with similarity score 0.8601661959458667: ['Trey Lyles']
#   Cluster with similarity score 0.8597187489918204: ['Xavier Tillman']
#   Cluster with similarity score 0.8588278405805824: ['Kenrich Williams']
#   Cluster with similarity score 0.8586283494196838: ['Shake Milton']
#   Cluster with similarity score 0.8580682878383219: ['Alec Burks']
#   Cluster with similarity score 0.8579983188170823: ['David Roddy']
#   Cluster with similarity score 0.8577343244225221: ['Joe Harris']
#   Cluster with similarity score 0.8569430773605924: ['Clint Capela']
#   Cluster with similarity score 0.8566546592583848: ['Isaac Okoro']
#   Cluster with similarity score 0.8562088462106: ['John Konchar']
#   Cluster with similarity score 0.8558825363239186: ['Jalen Duren']
#   Cluster with similarity score 0.8547998775089832: ['Hamidou Diallo']
#   Cluster with similarity score 0.8516840745493341: ['Brandon Clarke']
#   Cluster with similarity score 0.8516251136831825: ['Victor Oladipo']
#   Cluster with similarity score 0.8475536858632133: ['Josh Green']
#   Cluster with similarity score 0.845820531029282: ['Sam Hauser']
#   Cluster with similarity score 0.8455566447850188: ['Kevin Love']
#   Cluster with similarity score 0.8451852944606909: ['Karl-Anthony Towns']
#   Cluster with similarity score 0.8446400808843273: ['Georges Niang']
#   Cluster with similarity score 0.844343051497412: ['Ivica Zubac']
#   Cluster with similarity score 0.8431046824497501: ['Jordan Nwora']
#   Cluster with similarity score 0.842442681925669: ['Trendon Watford']
#   Cluster with similarity score 0.8419351727350664: ['AJ Griffin']
#   Cluster with similarity score 0.840987739494636: ['Jaren Jackson Jr.']
#   Cluster with similarity score 0.8408365805477535: ['Drew Eubanks']
#   Cluster with similarity score 0.840684401177134: ['Terrence Ross']
#   Cluster with similarity score 0.8402619941675307: ['Oshae Brissett']
#   Cluster with similarity score 0.8394104274333751: ['Cameron Payne']
#   Cluster with similarity score 0.8385719277970497: ['Damion Lee']
#   Cluster with similarity score 0.8376480113357389: ['Davion Mitchell']
#   Cluster with similarity score 0.8370415889184378: ['Brook Lopez']
#   Cluster with similarity score 0.836363977532344: ['Alex Caruso']
#   Cluster with similarity score 0.8359391388469665: ['Collin Sexton']
#   Cluster with similarity score 0.8350169599494297: ['Aaron Wiggins']
#   Cluster with similarity score 0.8327967788439669: ['Anthony Lamb']
#   Cluster with similarity score 0.8311489581991277: ['Marvin Bagley III']
#   Cluster with similarity score 0.829661572078443: ['Lonnie Walker IV']
#   Cluster with similarity score 0.8296027504269807: ['Delon Wright']
#   Cluster with similarity score 0.8290316905663041: ['Dyson Daniels']
#   Cluster with similarity score 0.8290025429273766: ['Christian Braun']
#   Cluster with similarity score 0.8284351490485695: ['Jock Landale']
#   Cluster with similarity score 0.826765175043197: ['John Wall']
#   Cluster with similarity score 0.8251906566128662: ['Daniel Gafford']
#   Cluster with similarity score 0.8242247158396485: ['Usman Garuba']
#   Cluster with similarity score 0.8241537764090641: ['Cory Joseph']
#   Cluster with similarity score 0.8239206618405504: ['Andre Drummond']
#   Cluster with similarity score 0.8237291764204837: ['Terence Davis']
#   Cluster with similarity score 0.8227386851369813: ['Obi Toppin']
#   Cluster with similarity score 0.8216051550592743: ['Thomas Bryant']
#   Cluster with similarity score 0.8213054523832554: ['Ben Simmons']
#   Cluster with similarity score 0.8193441251140726: ['Doug McDermott']
#   Cluster with similarity score 0.8181875984661556: ['Wenyen Gabriel']
#   Cluster with similarity score 0.8169543647148324: ['Dwight Powell']
#   Cluster with similarity score 0.8140806295081812: ['Nickeil Alexander-Walker']
#   Cluster with similarity score 0.8139963200223927: ['P.J. Tucker']
#   Cluster with similarity score 0.8138292837816732: ['Haywood Highsmith']
#   Cluster with similarity score 0.8129670091696045: ['Khris Middleton']
#   Cluster with similarity score 0.8127471971734237: ['Will Barton']
#   Cluster with similarity score 0.8125852860046513: ['Isaiah Jackson']
#   Cluster with similarity score 0.8121385913337992: ['Taurean Prince']
#   Cluster with similarity score 0.8117991197112: ['Lamar Stevens']
#   Cluster with similarity score 0.8115972079035252: ['Jaylin Williams']
#   Cluster with similarity score 0.8102181911625316: ['Seth Curry']
#   Cluster with similarity score 0.80892775569364: ['Steven Adams']
#   Cluster with similarity score 0.8069863826221118: ['Kendrick Nunn']
#   Cluster with similarity score 0.804433248097425: ['Paul Reed']
#   Cluster with similarity score 0.8041638906001951: ['Jeff Green']
#   Cluster with similarity score 0.8038531698329158: ['Luke Kennard']
#   Cluster with similarity score 0.8037086986902571: ['Robert Covington']
#   Cluster with similarity score 0.8030201308283466: ['Kevin Knox II']
#   Cluster with similarity score 0.8020563915203964: ['Theo Maledon']
#   Cluster with similarity score 0.8011741455409743: ['Matisse Thybulle']
#   Cluster with similarity score 0.8007583237295727: ['Cam Thomas']
#
# Clusters with similarity score threshold >= 0.7:
#   Cluster with similarity score 0.9927205049819267: ['Paolo Banchero']
#   Cluster with similarity score 0.9910677514947449: ['Pascal Siakam']
#   Cluster with similarity score 0.9907218723481154: ['Jaylen Brown']
#   Cluster with similarity score 0.9840968108491313: ['LeBron James']
#   Cluster with similarity score 0.9840660311593127: ['Julius Randle']
#   Cluster with similarity score 0.9838843115420738: ['Luka Doncic']
#   Cluster with similarity score 0.9832716949276415: ['Giannis Antetokounmpo']
#   Cluster with similarity score 0.9809920586076716: ['Joel Embiid']
#   Cluster with similarity score 0.9807495578806485: ['Zach LaVine']
#   Cluster with similarity score 0.9793078379574752: ['DeMar DeRozan']
#   Cluster with similarity score 0.9783934684394806: ['Kyle Kuzma']
#   Cluster with similarity score 0.9773317608518364: ['Jalen Green']
#   Cluster with similarity score 0.9747468331224342: ['Mikal Bridges']
#   Cluster with similarity score 0.9729858514286286: ['CJ McCollum']
#   Cluster with similarity score 0.9719739601535338: ['Kyrie Irving']
#   Cluster with similarity score 0.9710785685974892: ['Shai Gilgeous-Alexander']
#   Cluster with similarity score 0.9696479653771177: ['Lauri Markkanen']
#   Cluster with similarity score 0.9696454241110796: ['Franz Wagner']
#   Cluster with similarity score 0.969467571275337: ["De'Aaron Fox"]
#   Cluster with similarity score 0.9690689388582499: ['RJ Barrett']
#   Cluster with similarity score 0.9689780192583851: ['Bam Adebayo']
#   Cluster with similarity score 0.9685086241208964: ['Keldon Johnson']
#   Cluster with similarity score 0.9683709835127601: ['Anthony Edwards']
#   Cluster with similarity score 0.9681589612801281: ['Donovan Mitchell']
#   Cluster with similarity score 0.9674250678742424: ['Scottie Barnes']
#   Cluster with similarity score 0.9665951778845921: ['Stephen Curry']
#   Cluster with similarity score 0.965208388106513: ['Ja Morant']
#   Cluster with similarity score 0.9649152864212112: ['Josh Giddey']
#   Cluster with similarity score 0.9640609265748883: ['Nikola Vucevic']
#   Cluster with similarity score 0.9629943254075546: ['Aaron Gordon']
#   Cluster with similarity score 0.9623792738644352: ['Kristaps Porzingis']
#   Cluster with similarity score 0.9623646004585733: ['Buddy Hield']
#   Cluster with similarity score 0.962059707704873: ['Jordan Poole']
#   Cluster with similarity score 0.9618915960235448: ['Paul George']
#   Cluster with similarity score 0.9603548132259798: ['Damian Lillard']
#   Cluster with similarity score 0.9595183907495739: ['Terry Rozier']
#   Cluster with similarity score 0.9589751388761512: ['Tyler Herro']
#   Cluster with similarity score 0.9589525601411693: ['Alperen Sengun']
#   Cluster with similarity score 0.957986402760583: ['Nikola Jokic']
#   Cluster with similarity score 0.9574639725638181: ['Klay Thompson']
#   Cluster with similarity score 0.9571715156420317: ['Immanuel Quickley']
#   Cluster with similarity score 0.9571331852519553: ['Jaden Ivey']
#   Cluster with similarity score 0.9564178007575057: ['Devin Booker']
#   Cluster with similarity score 0.9553523743861392: ['P.J. Washington']
#   Cluster with similarity score 0.9553059133657921: ['Jalen Brunson']
#   Cluster with similarity score 0.9543032098313154: ['Kawhi Leonard']
#   Cluster with similarity score 0.9531905844279467: ['Bennedict Mathurin']
#   Cluster with similarity score 0.9530722194870402: ['Tobias Harris']
#   Cluster with similarity score 0.9528662194152248: ['Dejounte Murray']
#   Cluster with similarity score 0.9525592560850035: ['Jerami Grant']
#   Cluster with similarity score 0.9514529322760054: ['Desmond Bane']
#   Cluster with similarity score 0.9502464954638618: ['Harrison Barnes']
#   Cluster with similarity score 0.9501790517784667: ['Kevin Porter Jr.']
#   Cluster with similarity score 0.9500300184695158: ['Luguentz Dort']
#   Cluster with similarity score 0.9485642321197982: ['Jimmy Butler']
#   Cluster with similarity score 0.9485491654409423: ['Jamal Murray']
#   Cluster with similarity score 0.9479048800252805: ['Jrue Holiday']
#   Cluster with similarity score 0.9468639966468269: ['Kenyon Martin Jr.']
#   Cluster with similarity score 0.9459988409398602: ['Domantas Sabonis']
#   Cluster with similarity score 0.9458097983356276: ['Dillon Brooks']
#   Cluster with similarity score 0.945417134398848: ['Anthony Davis']
#   Cluster with similarity score 0.9444732345570522: ['Kevin Huerter']
#   Cluster with similarity score 0.9435416493948299: ['Spencer Dinwiddie']
#   Cluster with similarity score 0.943491496926229: ['Jordan Clarkson']
#   Cluster with similarity score 0.9418296584427431: ['Deandre Ayton']
#   Cluster with similarity score 0.940667583946705: ['Russell Westbrook']
#   Cluster with similarity score 0.9404739207443152: ['Keegan Murray']
#   Cluster with similarity score 0.9392749046578394: ["D'Angelo Russell"]
#   Cluster with similarity score 0.9392336846712848: ['Saddiq Bey']
#   Cluster with similarity score 0.9390734380901319: ['Malik Beasley']
#   Cluster with similarity score 0.9387476628175023: ['Jabari Smith Jr.']
#   Cluster with similarity score 0.9383802582222143: ['Caris LeVert']
#   Cluster with similarity score 0.9380170451504646: ['Kevin Durant']
#   Cluster with similarity score 0.9375890308897896: ['Kelly Olynyk']
#   Cluster with similarity score 0.9368976583755232: ['Deni Avdija']
#   Cluster with similarity score 0.9365724003222996: ['Bruce Brown']
#   Cluster with similarity score 0.9353050300888102: ['Evan Mobley']
#   Cluster with similarity score 0.9346478620366613: ['Tim Hardaway Jr.']
#   Cluster with similarity score 0.9343374971927173: ['Bradley Beal']
#   Cluster with similarity score 0.9336423269682974: ['Christian Wood']
#   Cluster with similarity score 0.9326706331723691: ['Derrick White']
#   Cluster with similarity score 0.9325371432310843: ['Jalen Williams']
#   Cluster with similarity score 0.9291186980458868: ["Royce O'Neale"]
#   Cluster with similarity score 0.9268673817966834: ['Anfernee Simons']
#   Cluster with similarity score 0.92634533210595: ['James Harden']
#   Cluster with similarity score 0.925830145842022: ['Trey Murphy III']
#   Cluster with similarity score 0.9254444181158504: ['Malcolm Brogdon']
#   Cluster with similarity score 0.9251396000489099: ['Wendell Carter Jr.']
#   Cluster with similarity score 0.9250700207178181: ['Michael Porter Jr.']
#   Cluster with similarity score 0.924891609113557: ['Jaden McDaniels']
#   Cluster with similarity score 0.9247493506414161: ['Josh Hart']
#   Cluster with similarity score 0.9247473286132672: ['Malik Monk']
#   Cluster with similarity score 0.9247255016838724: ['Darius Garland']
#   Cluster with similarity score 0.9240233544747254: ['Tyrese Maxey']
#   Cluster with similarity score 0.9233288161472052: ['John Collins']
#   Cluster with similarity score 0.9229533384278362: ['Jusuf Nurkic']
#   Cluster with similarity score 0.9225258630484511: ['Brandon Ingram']
#   Cluster with similarity score 0.9216679256003089: ['Fred VanVleet']
#   Cluster with similarity score 0.9206430561145371: ['Kelly Oubre Jr.']
#   Cluster with similarity score 0.9202194755758708: ["De'Andre Hunter"]
#   Cluster with similarity score 0.9181066018867775: ['Bobby Portis']
#   Cluster with similarity score 0.9176205322377388: ['Bojan Bogdanovic']
#   Cluster with similarity score 0.9173442892639628: ['Zach Collins']
#   Cluster with similarity score 0.9172826593799128: ['Max Strus']
#   Cluster with similarity score 0.9158935899891545: ['Naji Marshall']
#   Cluster with similarity score 0.9149334946039943: ['Jeremy Sochan']
#   Cluster with similarity score 0.9136694514075273: ['Talen Horton-Tucker']
#   Cluster with similarity score 0.9135284763406564: ['Trae Young']
#   Cluster with similarity score 0.9128843323914769: ['Santi Aldama']
#   Cluster with similarity score 0.9120996449340145: ['LaMelo Ball']
#   Cluster with similarity score 0.9116658956123587: ['Jalen McDaniels']
#   Cluster with similarity score 0.9115363377036844: ['Markelle Fultz']
#   Cluster with similarity score 0.9110170918242494: ['Naz Reid']
#   Cluster with similarity score 0.910921696113231: ['Jonas Valanciunas']
#   Cluster with similarity score 0.9097178739948597: ['Norman Powell']
#   Cluster with similarity score 0.9095951453509445: ['Quentin Grimes']
#   Cluster with similarity score 0.9095193182043224: ['Jarrett Allen']
#   Cluster with similarity score 0.9093689329267086: ['Kyle Anderson']
#   Cluster with similarity score 0.9093342487192593: ['Tari Eason']
#   Cluster with similarity score 0.9083895838499836: ['Caleb Martin']
#   Cluster with similarity score 0.9079184667475383: ['Patrick Williams']
#   Cluster with similarity score 0.90765499383358: ['Jarred Vanderbilt']
#   Cluster with similarity score 0.9074457857473901: ['Shaedon Sharpe']
#   Cluster with similarity score 0.907178777648903: ['Cole Anthony']
#   Cluster with similarity score 0.9055257782318733: ['Grant Williams']
#   Cluster with similarity score 0.9046220442745293: ['Marcus Morris Sr.']
#   Cluster with similarity score 0.9044958913960142: ['Aaron Nesmith']
#   Cluster with similarity score 0.9044267671819926: ['Tyrese Haliburton']
#   Cluster with similarity score 0.903205754001861: ['Terance Mann']
#   Cluster with similarity score 0.9031734946957156: ['Torrey Craig']
#   Cluster with similarity score 0.9028758655467822: ['Ayo Dosunmu']
#   Cluster with similarity score 0.9027339162196746: ['O.G. Anunoby']
#   Cluster with similarity score 0.9015958647189855: ['Draymond Green']
#   Cluster with similarity score 0.9009970364964439: ['Tre Jones']
#   Cluster with similarity score 0.9009536673494101: ['Dennis Schroder']
#   Cluster with similarity score 0.8997776544326804: ['Jakob Poeltl']
#   Cluster with similarity score 0.89913610402794: ['Gordon Hayward']
#   Cluster with similarity score 0.8981216538126572: ['Dorian Finney-Smith']
#   Cluster with similarity score 0.8977836520320982: ['Andrew Nembhard']
#   Cluster with similarity score 0.8973897734117117: ['Eric Gordon']
#   Cluster with similarity score 0.8973508081469129: ['Mason Plumlee']
#   Cluster with similarity score 0.8967344967987744: ['Chris Boucher']
#   Cluster with similarity score 0.8965392159805904: ['Jonathan Kuminga']
#   Cluster with similarity score 0.8962238952463538: ['Gary Trent Jr.']
#   Cluster with similarity score 0.8943537675414622: ['Tyus Jones']
#   Cluster with similarity score 0.8940227635498835: ['Reggie Bullock']
#   Cluster with similarity score 0.8937880251845057: ['Grayson Allen']
#   Cluster with similarity score 0.8937644846983295: ['Donte DiVincenzo']
#   Cluster with similarity score 0.8931580817188184: ['Al Horford']
#   Cluster with similarity score 0.8926113985145467: ['Kyle Lowry']
#   Cluster with similarity score 0.8919625906107171: ['Josh Okogie']
#   Cluster with similarity score 0.8911468336308512: ['Jevon Carter']
#   Cluster with similarity score 0.8908066908153972: ['Chris Paul']
#   Cluster with similarity score 0.8900836286049415: ['Coby White']
#   Cluster with similarity score 0.8896320706279066: ['Mike Conley']
#   Cluster with similarity score 0.8871783643118137: ['Nicolas Batum']
#   Cluster with similarity score 0.8864013056007722: ['Onyeka Okongwu']
#   Cluster with similarity score 0.8860936581925745: ['Austin Reaves']
#   Cluster with similarity score 0.8853804567733516: ['Marcus Smart']
#   Cluster with similarity score 0.8851767117450324: ['Andrew Wiggins']
#   Cluster with similarity score 0.8847757955170543: ['Jaylen Nowell']
#   Cluster with similarity score 0.8837664663116885: ['Bogdan Bogdanovic']
#   Cluster with similarity score 0.882572264598588: ['Killian Hayes']
#   Cluster with similarity score 0.8820420115597393: ['Cedi Osman']
#   Cluster with similarity score 0.8814614974718654: ['Josh Richardson']
#   Cluster with similarity score 0.8812872648905189: ['Patrick Beverley']
#   Cluster with similarity score 0.8811393226529363: ['Keita Bates-Diop']
#   Cluster with similarity score 0.8802181199007997: ['Devin Vassell']
#   Cluster with similarity score 0.8800802850113391: ['Monte Morris']
#   Cluster with similarity score 0.8799995895118955: ['Herbert Jones']
#   Cluster with similarity score 0.8789685898399943: ['Kentavious Caldwell-Pope']
#   Cluster with similarity score 0.8783015877042799: ['Pat Connaughton']
#   Cluster with similarity score 0.8781348835567315: ['Myles Turner']
#   Cluster with similarity score 0.8777372965162696: ["De'Anthony Melton"]
#   Cluster with similarity score 0.8769390456758649: ['T.J. McConnell']
#   Cluster with similarity score 0.8758536883201536: ['Jalen Smith']
#   Cluster with similarity score 0.8757582578990117: ['Jalen Suggs']
#   Cluster with similarity score 0.8742631736931474: ['Isaiah Stewart']
#   Cluster with similarity score 0.8740858822322919: ['Zion Williamson']
#   Cluster with similarity score 0.8739015488122589: ['Rui Hachimura']
#   Cluster with similarity score 0.8733615073666537: ['Troy Brown Jr.']
#   Cluster with similarity score 0.8727307522396258: ['Isaiah Hartenstein']
#   Cluster with similarity score 0.8717601745514474: ['Precious Achiuwa']
#   Cluster with similarity score 0.8717167420365386: ['Rudy Gobert']
#   Cluster with similarity score 0.8702120242074088: ['Reggie Jackson']
#   Cluster with similarity score 0.8701694363151814: ['Dennis Smith Jr.']
#   Cluster with similarity score 0.8699068113023414: ['Larry Nance Jr.']
#   Cluster with similarity score 0.8690041927266836: ['Malaki Branham']
#   Cluster with similarity score 0.8687488081276327: ["Devonte' Graham"]
#   Cluster with similarity score 0.8684362555834156: ['Corey Kispert']
#   Cluster with similarity score 0.86757161487591: ['Isaiah Joe']
#   Cluster with similarity score 0.8673011146685111: ['Bones Hyland']
#   Cluster with similarity score 0.867191825001341: ['Gabe Vincent']
#   Cluster with similarity score 0.8667066467617288: ['Jalen Johnson']
#   Cluster with similarity score 0.8659659828387282: ['Bol Bol']
#   Cluster with similarity score 0.8645704131927803: ['Kevon Looney']
#   Cluster with similarity score 0.8644906391425404: ['Moritz Wagner']
#   Cluster with similarity score 0.8639547912578583: ['Jordan Goodwin']
#   Cluster with similarity score 0.863697415358257: ['Jose Alvarado']
#   Cluster with similarity score 0.8617986366689415: ['Cameron Johnson']
#   Cluster with similarity score 0.8604184625162182: ['Tre Mann']
#   Cluster with similarity score 0.8601661959458667: ['Trey Lyles']
#   Cluster with similarity score 0.8597187489918204: ['Xavier Tillman']
#   Cluster with similarity score 0.8588278405805824: ['Kenrich Williams']
#   Cluster with similarity score 0.8586283494196838: ['Shake Milton']
#   Cluster with similarity score 0.8580682878383219: ['Alec Burks']
#   Cluster with similarity score 0.8579983188170823: ['David Roddy']
#   Cluster with similarity score 0.8577343244225221: ['Joe Harris']
#   Cluster with similarity score 0.8569430773605924: ['Clint Capela']
#   Cluster with similarity score 0.8566546592583848: ['Isaac Okoro']
#   Cluster with similarity score 0.8562088462106: ['John Konchar']
#   Cluster with similarity score 0.8558825363239186: ['Jalen Duren']
#   Cluster with similarity score 0.8547998775089832: ['Hamidou Diallo']
#   Cluster with similarity score 0.8516840745493341: ['Brandon Clarke']
#   Cluster with similarity score 0.8516251136831825: ['Victor Oladipo']
#   Cluster with similarity score 0.8475536858632133: ['Josh Green']
#   Cluster with similarity score 0.845820531029282: ['Sam Hauser']
#   Cluster with similarity score 0.8455566447850188: ['Kevin Love']
#   Cluster with similarity score 0.8451852944606909: ['Karl-Anthony Towns']
#   Cluster with similarity score 0.8446400808843273: ['Georges Niang']
#   Cluster with similarity score 0.844343051497412: ['Ivica Zubac']
#   Cluster with similarity score 0.8431046824497501: ['Jordan Nwora']
#   Cluster with similarity score 0.842442681925669: ['Trendon Watford']
#   Cluster with similarity score 0.8419351727350664: ['AJ Griffin']
#   Cluster with similarity score 0.840987739494636: ['Jaren Jackson Jr.']
#   Cluster with similarity score 0.8408365805477535: ['Drew Eubanks']
#   Cluster with similarity score 0.840684401177134: ['Terrence Ross']
#   Cluster with similarity score 0.8402619941675307: ['Oshae Brissett']
#   Cluster with similarity score 0.8394104274333751: ['Cameron Payne']
#   Cluster with similarity score 0.8385719277970497: ['Damion Lee']
#   Cluster with similarity score 0.8376480113357389: ['Davion Mitchell']
#   Cluster with similarity score 0.8370415889184378: ['Brook Lopez']
#   Cluster with similarity score 0.836363977532344: ['Alex Caruso']
#   Cluster with similarity score 0.8359391388469665: ['Collin Sexton']
#   Cluster with similarity score 0.8350169599494297: ['Aaron Wiggins']
#   Cluster with similarity score 0.8327967788439669: ['Anthony Lamb']
#   Cluster with similarity score 0.8311489581991277: ['Marvin Bagley III']
#   Cluster with similarity score 0.829661572078443: ['Lonnie Walker IV']
#   Cluster with similarity score 0.8296027504269807: ['Delon Wright']
#   Cluster with similarity score 0.8290316905663041: ['Dyson Daniels']
#   Cluster with similarity score 0.8290025429273766: ['Christian Braun']
#   Cluster with similarity score 0.8284351490485695: ['Jock Landale']
#   Cluster with similarity score 0.826765175043197: ['John Wall']
#   Cluster with similarity score 0.8251906566128662: ['Daniel Gafford']
#   Cluster with similarity score 0.8242247158396485: ['Usman Garuba']
#   Cluster with similarity score 0.8241537764090641: ['Cory Joseph']
#   Cluster with similarity score 0.8239206618405504: ['Andre Drummond']
#   Cluster with similarity score 0.8237291764204837: ['Terence Davis']
#   Cluster with similarity score 0.8227386851369813: ['Obi Toppin']
#   Cluster with similarity score 0.8216051550592743: ['Thomas Bryant']
#   Cluster with similarity score 0.8213054523832554: ['Ben Simmons']
#   Cluster with similarity score 0.8193441251140726: ['Doug McDermott']
#   Cluster with similarity score 0.8181875984661556: ['Wenyen Gabriel']
#   Cluster with similarity score 0.8169543647148324: ['Dwight Powell']
#   Cluster with similarity score 0.8140806295081812: ['Nickeil Alexander-Walker']
#   Cluster with similarity score 0.8139963200223927: ['P.J. Tucker']
#   Cluster with similarity score 0.8138292837816732: ['Haywood Highsmith']
#   Cluster with similarity score 0.8129670091696045: ['Khris Middleton']
#   Cluster with similarity score 0.8127471971734237: ['Will Barton']
#   Cluster with similarity score 0.8125852860046513: ['Isaiah Jackson']
#   Cluster with similarity score 0.8121385913337992: ['Taurean Prince']
#   Cluster with similarity score 0.8117991197112: ['Lamar Stevens']
#   Cluster with similarity score 0.8115972079035252: ['Jaylin Williams']
#   Cluster with similarity score 0.8102181911625316: ['Seth Curry']
#   Cluster with similarity score 0.80892775569364: ['Steven Adams']
#   Cluster with similarity score 0.8069863826221118: ['Kendrick Nunn']
#   Cluster with similarity score 0.804433248097425: ['Paul Reed']
#   Cluster with similarity score 0.8041638906001951: ['Jeff Green']
#   Cluster with similarity score 0.8038531698329158: ['Luke Kennard']
#   Cluster with similarity score 0.8037086986902571: ['Robert Covington']
#   Cluster with similarity score 0.8030201308283466: ['Kevin Knox II']
#   Cluster with similarity score 0.8020563915203964: ['Theo Maledon']
#   Cluster with similarity score 0.8011741455409743: ['Matisse Thybulle']
#   Cluster with similarity score 0.8007583237295727: ['Cam Thomas']
#   Cluster with similarity score 0.7998946202925405: ['Nic Claxton']
#   Cluster with similarity score 0.7995507182978916: ['Daishen Nix']
#   Cluster with similarity score 0.7983883488865636: ['JaMychal Green']
#   Cluster with similarity score 0.7949295125626394: ['James Wiseman']
#   Cluster with similarity score 0.7947888076202335: ['Josh Christopher']
#   Cluster with similarity score 0.7940194674162705: ['Thaddeus Young']
#   Cluster with similarity score 0.793715245207798: ['Mike Muscala']
#   Cluster with similarity score 0.7929333352601277: ['Aleksej Pokusevski']
#   Cluster with similarity score 0.7915025928620385: ['Derrick Jones Jr.']
#   Cluster with similarity score 0.7914272392056446: ['Joe Ingles']
#   Cluster with similarity score 0.7912429862090014: ['Ochai Agbaji']
#   Cluster with similarity score 0.7910650374899081: ['Nassir Little']
#   Cluster with similarity score 0.7907704574425595: ['Cam Reddish']
#   Cluster with similarity score 0.7905447457208413: ['Dario Saric']
#   Cluster with similarity score 0.7899462604653095: ['Isaiah Livers']
#   Cluster with similarity score 0.7882062246038803: ['Mo Bamba']
#   Cluster with similarity score 0.788187313850341: ['Justise Winslow']
#   Cluster with similarity score 0.787084566344276: ['Gary Harris']
#   Cluster with similarity score 0.7866712186628328: ['Mitchell Robinson']
#   Cluster with similarity score 0.7853959999599959: ['Mark Williams']
#   Cluster with similarity score 0.784267296437159: ['JT Thor']
#   Cluster with similarity score 0.7841989658909142: ['Ish Wainright']
#   Cluster with similarity score 0.7822000756161408: ['Sandro Mamukelashvili']
#   Cluster with similarity score 0.7809291612575814: ['Chris Duarte']
#   Cluster with similarity score 0.7805321862210655: ['Romeo Langford']
#   Cluster with similarity score 0.7801668737492959: ['Chimezie Metu']
#   Cluster with similarity score 0.7800683205067468: ['Dean Wade']
#   Cluster with similarity score 0.7791296639067058: ['Goran Dragic']
#   Cluster with similarity score 0.7760835230442432: ['Jeremiah Robinson-Earl']
#   Cluster with similarity score 0.7748438457591306: ['Yuta Watanabe']
#   Cluster with similarity score 0.7734329431158422: ["Jae'Sean Tate"]
#   Cluster with similarity score 0.7729744261322036: ['Miles McBride']
#   Cluster with similarity score 0.7722939857146953: ['Rudy Gay']
#   Cluster with similarity score 0.7722048387731919: ['Eugene Omoruyi']
#   Cluster with similarity score 0.7708175531405268: ['Darius Bazley']
#   Cluster with similarity score 0.768955959752174: ['R.J. Hampton']
#   Cluster with similarity score 0.7682161410622546: ['Edmond Sumner']
#   Cluster with similarity score 0.764767945875244: ['Blake Wesley']
#   Cluster with similarity score 0.764503700456822: ['Jaden Hardy']
#   Cluster with similarity score 0.7623787555381993: ['T.J. Warren']
#   Cluster with similarity score 0.7613392326179877: ['Aaron Holiday']
#   Cluster with similarity score 0.7605100706266091: ['Landry Shamet']
#   Cluster with similarity score 0.7603968960312448: ['MarJon Beauchamp']
#   Cluster with similarity score 0.7596704145591192: ['Kris Dunn']
#   Cluster with similarity score 0.7593647908418087: ['Walker Kessler']
#   Cluster with similarity score 0.7591043457183629: ['Austin Rivers']
#   Cluster with similarity score 0.7581242697968121: ['George Hill']
#   Cluster with similarity score 0.7572614880542393: ['Moses Moody']
#   Cluster with similarity score 0.7563782786664639: ['Vlatko Cancar']
#   Cluster with similarity score 0.7561633754089554: ['Willy Hernangomez']
#   Cluster with similarity score 0.752042402484337: ['Zeke Nnaji']
#   Cluster with similarity score 0.7516668790763428: ['Christian Koloko']
#   Cluster with similarity score 0.7511267655122705: ['Ty Jerome']
#   Cluster with similarity score 0.7483547069616517: ['Simone Fontecchio']
#   Cluster with similarity score 0.747931670277618: ['Isaiah Roby']
#   Cluster with similarity score 0.7476633163897758: ['Maxi Kleber']
#   Cluster with similarity score 0.7474226493897701: ['Malachi Flynn']
#   Cluster with similarity score 0.7468340541053377: ['Jordan McLaughlin']
#   Cluster with similarity score 0.7466078681826713: ['Ricky Rubio']
#   Cluster with similarity score 0.7437550333263472: ['Justin Holiday']
#   Cluster with similarity score 0.7408342245674242: ['Blake Griffin']
#   Cluster with similarity score 0.7403960292306905: ['Ousmane Dieng']
#   Cluster with similarity score 0.7402616148364358: ['Bryce McGowens']
#   Cluster with similarity score 0.7399852187466516: ['Jaxson Hayes']
#   Cluster with similarity score 0.7373268067498101: ['Robert Williams III']
#   Cluster with similarity score 0.7372725973454947: ['Luke Kornet']
#   Cluster with similarity score 0.7370476969889435: ['Payton Pritchard']
#   Cluster with similarity score 0.7368112886268293: ['Montrezl Harrell']
#   Cluster with similarity score 0.7356702857948011: ['Danuel House Jr.']
#   Cluster with similarity score 0.7354983780034295: ['Goga Bitadze']
#   Cluster with similarity score 0.7352632131928946: ['Charles Bassey']
#   Cluster with similarity score 0.7331539933620546: ["Day'Ron Sharpe"]
#   Cluster with similarity score 0.7318523814806646: ['Jabari Walker']
#   Cluster with similarity score 0.7317255136055612: ['Juancho Hernangomez']
#   Cluster with similarity score 0.7276796254203206: ['Keon Johnson']
#   Cluster with similarity score 0.7276443754867186: ['Juan Toscano-Anderson']
#   Cluster with similarity score 0.7270127433039542: ['Nick Richards']
#   Cluster with similarity score 0.7264697446703469: ['James Bouknight']
#   Cluster with similarity score 0.7263284490589823: ['Wesley Matthews']
#   Cluster with similarity score 0.7227783504244505: ['Garrison Mathews']
#   Cluster with similarity score 0.7227643539374391: ['Dewayne Dedmon']
#   Cluster with similarity score 0.7214406394388043: ['Frank Ntilikina']
#   Cluster with similarity score 0.7207788468056754: ['TyTy Washington Jr.']
#   Cluster with similarity score 0.7201449142343366: ['Chuma Okeke']
#   Cluster with similarity score 0.719188120010905: ['Johnny Davis']
#   Cluster with similarity score 0.7181234517705819: ['Javonte Green']
#   Cluster with similarity score 0.7167473052354999: ['Cade Cunningham']
#   Cluster with similarity score 0.7165245006459896: ['Ziaire Williams']
#   Cluster with similarity score 0.7160055883621841: ['Kai Jones']
#   Cluster with similarity score 0.7139582875036798: ['Ish Smith']
#   Cluster with similarity score 0.7121692573589058: ['Lindy Waters III']
#   Cluster with similarity score 0.7117897164300042: ['Svi Mykhailiuk']
#   Cluster with similarity score 0.7106271728440388: ['Taj Gibson']
#   Cluster with similarity score 0.7095214920500064: ['Patty Mills']
#   Cluster with similarity score 0.7094846007386227: ['Stanley Johnson']
#   Cluster with similarity score 0.7090350064992683: ['Duncan Robinson']
#   Cluster with similarity score 0.7070841751749715: ['Bismack Biyombo']
#   Cluster with similarity score 0.7068743702761877: ['Caleb Houstan']
#   Cluster with similarity score 0.7064801880608617: ['Saben Lee']
#   Cluster with similarity score 0.7052313014705427: ['Duane Washington Jr.']

# %%
# Define threshold values
thresholds = [0.9, 0.8, 0.7]

# Initialize dictionaries to store clusters for each threshold
clusters = {threshold: {} for threshold in thresholds}

# Iterate through similarity scores and group players into clusters for each threshold
for player, score in similar_players_dict.items():
    for threshold in thresholds:
        if score >= threshold:
            if threshold in clusters and len(clusters[threshold]) < 10:  # Limit to top 10 players per cluster
                if score in clusters[threshold]:
                    if len(clusters[threshold][score]) < 10:
                        clusters[threshold][score].append(player)
                else:
                    clusters[threshold][score] = [player]

# Display clusters
print("Clusters of players similar to Jayson Tatum:")
for threshold in thresholds:
    print(f"\nTop 10 clusters with similarity score threshold >= {threshold}:")
    for score, players in clusters[threshold].items():
        print(f"  Cluster with similarity score {score}: {players}")
# Out:
# Clusters of players similar to Jayson Tatum:
#
# Top 10 clusters with similarity score threshold >= 0.9:
#   Cluster with similarity score 0.9927205049819267: ['Paolo Banchero']
#   Cluster with similarity score 0.9910677514947449: ['Pascal Siakam']
#   Cluster with similarity score 0.9907218723481154: ['Jaylen Brown']
#   Cluster with similarity score 0.9840968108491313: ['LeBron James']
#   Cluster with similarity score 0.9840660311593127: ['Julius Randle']
#   Cluster with similarity score 0.9838843115420738: ['Luka Doncic']
#   Cluster with similarity score 0.9832716949276415: ['Giannis Antetokounmpo']
#   Cluster with similarity score 0.9809920586076716: ['Joel Embiid']
#   Cluster with similarity score 0.9807495578806485: ['Zach LaVine']
#   Cluster with similarity score 0.9793078379574752: ['DeMar DeRozan']
#
# Top 10 clusters with similarity score threshold >= 0.8:
#   Cluster with similarity score 0.9927205049819267: ['Paolo Banchero']
#   Cluster with similarity score 0.9910677514947449: ['Pascal Siakam']
#   Cluster with similarity score 0.9907218723481154: ['Jaylen Brown']
#   Cluster with similarity score 0.9840968108491313: ['LeBron James']
#   Cluster with similarity score 0.9840660311593127: ['Julius Randle']
#   Cluster with similarity score 0.9838843115420738: ['Luka Doncic']
#   Cluster with similarity score 0.9832716949276415: ['Giannis Antetokounmpo']
#   Cluster with similarity score 0.9809920586076716: ['Joel Embiid']
#   Cluster with similarity score 0.9807495578806485: ['Zach LaVine']
#   Cluster with similarity score 0.9793078379574752: ['DeMar DeRozan']
#
# Top 10 clusters with similarity score threshold >= 0.7:
#   Cluster with similarity score 0.9927205049819267: ['Paolo Banchero']
#   Cluster with similarity score 0.9910677514947449: ['Pascal Siakam']
#   Cluster with similarity score 0.9907218723481154: ['Jaylen Brown']
#   Cluster with similarity score 0.9840968108491313: ['LeBron James']
#   Cluster with similarity score 0.9840660311593127: ['Julius Randle']
#   Cluster with similarity score 0.9838843115420738: ['Luka Doncic']
#   Cluster with similarity score 0.9832716949276415: ['Giannis Antetokounmpo']
#   Cluster with similarity score 0.9809920586076716: ['Joel Embiid']
#   Cluster with similarity score 0.9807495578806485: ['Zach LaVine']
#   Cluster with similarity score 0.9793078379574752: ['DeMar DeRozan']
